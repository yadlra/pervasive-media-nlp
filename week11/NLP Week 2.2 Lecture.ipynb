# %%
#Import all necessary packages
import numpy as np
import pandas as pd 
import re
from sklearn.feature_extraction import _stop_words as stop_words 
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
from sklearn.metrics.pairwise import cosine_similarity as cosine
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:992)>

# %% [markdown]
# # Week 2.2 Word Importance and Topic Modelling

# %% [markdown]
# ### TF/IDF
#
# Up until this point, we've seen how counting words, and looking at the most frequent can gives us some insight into a single document. If we want to start comparing documents with more certainty, or getting smarter about our representations, we can try and get a set of numbers for each documents that not only represents **word frequency**, but also **word importance**.
#
# What we will end up with is a measurement called **TF/IDF** or **T**erm **F**requency x **I**nverse **D**ocument **F**requency.
#
# ### TF
#
# **TF** stands for **term frequency** and we've been using it a lot already in our Bags of Words. By itself, it tells us how many times a particular term appears in a document. Can we do better?

# %%
import re
fs = open('data/hacking.txt', 'r') 
book = fs.read()

# %%
#Called once for each document
#Every time you update this function you need to run the cell again (Shift + Enter)
def my_tokeniser(doc):
    #Split on spaces
    tokens = re.split(r'[-\s.,;!?]+', doc)
    return [lem.lemmatize(t.lower()) for t in tokens if not t in stop_words.ENGLISH_STOP_WORDS]

# %%
#Using the CountVectorizer to get a bag of words using a custom tokeniser
count_vectoriser = CountVectorizer(tokenizer=my_tokeniser)
bag_of_words = count_vectoriser.fit_transform([book])
print(bag_of_words.todense().shape)
# Out:
# (1, 11770)

# %%
vocab = count_vectoriser.get_feature_names_out()
bag_of_words_df = pd.DataFrame(bag_of_words.todense(), columns = vocab)

# %%
#Topic 20 most common words (we've already removed STOP WORDS)
bag_of_words_df.iloc[0].sort_values()[-20:]
# Out:
# machine      249
# people       277
# phone        289
# network      297
# worm         298
# hacking      301
# day          303
# mendax       307
# police       323
# anthrax      338
# phoenix      361
# just         361
# like         367
# didn't       378
# electron     383
# time         439
# par          501
# hacker       708
# '            823
# computer    1020
# Name: 0, dtype: int64

# %% [markdown]
# ### TF Seems OK?
#
# Consider our book and some of its most common words
#
# - computer
# - hacking
# - security
# - police
# - network
#
# ### Normalised Term Frequency
#
# These words seem to represent key topics of the book quite well. However, what about **mother**? This appears 113  times across the book, out of a vocabulary of  approx. 13,000 words. Compare this to a WhatsApp conversation that me and my sister had about our family Christmas that has the word **mother** 5 times in with a vocabulary of about 50 words. When we compare just **term frequency**, it seems like the hacking book is far, far more (~20 times) about mothers than this text message chain. But thats not really the case.
#
# We use **normalised term frequency** to account for this, where the length of the document is used alongside the count to adjust for this.

# %%
bag_of_words_df["mother"][0]
# Out:
# 113

# %%
#Divide term frequency by total number of unique words (vocab size)
book_tf = bag_of_words_df["mother"][0] / len(vocab)
text_msg_tf = 5.0 / 50
#Much bigger normalised term frequency for text msgs
print(book_tf, text_msg_tf)
# Out:
# 0.009600679694137639 0.1

# %% [markdown]
# ### IDF
#
# **IDF** stands for **I**nverse **D**ocument **F**requency and it tells us how important a word is in a particular document in comparison to the rest of the corpus. Up until this point we've been considering the book as one big document, but now we're going to take each chapter on its own, to see if we can see if we can highlight differences between them.
#
# We can see below that most chapters have the terms **computer** and **hacker** featuring pretty heavily.
#
# The **IDF** is the ratio of all documents in comparison to how many documents the term appears in.
#
# It tells us how surprising is it that this word appeared here, given what we know about all the documents.

# %% [markdown]
# ## Getting the Vector for each document (chapter)
#
# First, we use a **regex** to split it into chapters, as there is a recognisable formatting to this. This means our corpus is the whole novel, with each chapter considered a new document and we store the whole thing as a 1D array. Each item in the array is a string containing a chapter's worth of text.
#
# ### Examining the highest TF values
#
# Looking at the Term Frequency (bag of words) for each chapter shows that each chapter has quite similar high frequency words like ``computer`` and ``hacker``. This isn't particularly useful if we want a representation that highlights the important terms **to that chapter**.

# %%
chapters = re.split(r'\s\s\s\s\s\sChapter+', book)

# %%
count_vectoriser = CountVectorizer(tokenizer=my_tokeniser)
bag_of_words = count_vectoriser.fit_transform(chapters)
print(bag_of_words.todense().shape)
# Out:
# (11, 11770)

# %%
bag_of_words_df = pd.DataFrame(bag_of_words.todense(), columns = vocab)
for i in range(len(bag_of_words_df)):
    print("chapter", i)
    print(bag_of_words_df.iloc[i].sort_values(ascending = False).head(10))
# Out:
# chapter 0
# book           38
# underground    25
# hacker         23
# computer       21
# mountain       19
# black          18
# par            18
# like           13
# suelette       13
# new            12
# Name: 0, dtype: int64
# chapter 1
# computer    288
# worm        261
# nasa        114
# account     102
# hacker       99
# span         95
# network      86
# people       82
# time         74
# like         70
# Name: 1, dtype: int64
# chapter 2
# par         180
# network      65
# hacker       64
# force        61
# computer     55
# alto         45
# like         41
# theorem      40
# time         39
# didn't       38
# Name: 2, dtype: int64
# chapter 3
# par         261
# theorem      48
# '            45
# didn't       37
# agent        37
# room         36
# secret       36
# computer     36
# hacker       33
# service      33
# Name: 3, dtype: int64
# chapter 4
# '           226
# phoenix     196
# electron    178
# computer    140
# hacker       88
# machine      88
# zardoz       74
# deszip       61
# just         56
# file         56
# Name: 4, dtype: int64
# chapter 5
# electron    134
# '           105
# phoenix     103
# computer     51
# time         40
# didn't       39
# said         36
# hacker       35
# day          34
# hacking      31
# Name: 5, dtype: int64
# chapter 6
# pad         138
# hacker       95
# computer     89
# gandalf      71
# police       55
# hacking      46
# case         41
# time         40
# wandii       39
# day          36
# Name: 6, dtype: int64
# chapter 7
# mendax       124
# computer     109
# hacker        81
# nortel        58
# admin         43
# prime         42
# network       40
# line          38
# suspect       36
# telephone     35
# Name: 7, dtype: int64
# chapter 8
# mendax      146
# prime        93
# '            92
# police       79
# hacker       73
# suspect      72
# court        60
# afp          53
# computer     49
# case         47
# Name: 8, dtype: int64
# chapter 9
# anthrax     179
# x            58
# number       50
# computer     47
# time         43
# '            42
# like         40
# father       39
# program      38
# phone        36
# Name: 9, dtype: int64
# chapter 10
# '            179
# anthrax      157
# computer     135
# work          99
# hacker        97
# police        93
# project       88
# gutenberg     87
# 1             77
# day           62
# Name: 10, dtype: int64

# %% [markdown]
# ### Examining the highest TF/IDF values
#
# Now we want to see which words are important to each chapter. Interestingly we've lost all of the words like `computer` and `hacking`, because they're surprising or indicative of that chapter, given the whole corpus. These words are the words that tell us the most about each chapter.
#
# It seems likes names (of people and of viruses?) are important distinctions between chapters.
#
# We also did lemmatisation instead of stemming and often have the same word, and its possesive version in a chapter (`anthrax` and `anthrax's`). Maybe stemming would be better?

# %%
#Using the TFIDF Vectorizer to get TFIDF vectors with custom tokeniser
tfidf_vectoriser = TfidfVectorizer(tokenizer=my_tokeniser)
tfidf = tfidf_vectoriser.fit_transform(chapters)
print(tfidf.todense().shape)
# Out:
# (11, 11770)

# %%
tfidf_df = pd.DataFrame(tfidf.todense(), columns = vocab)
for i in range(len(tfidf_df)):
    print("chapter", i)
    print(tfidf_df.iloc[i].sort_values(ascending = False).head(10))
# Out:
# chapter 0
# book             0.259165
# mountain         0.250175
# suelette         0.194637
# julian           0.175161
# par              0.158727
# underground      0.156855
# dreyfus          0.149721
# `underground'    0.149721
# assange          0.149721
# hacker           0.144307
# Name: 0, dtype: float64
# chapter 1
# worm        0.455574
# computer    0.357677
# span        0.247602
# nasa        0.198986
# mcmahon     0.149069
# account     0.126677
# w**k        0.126167
# bowen       0.125104
# hacker      0.122951
# network     0.106806
# Name: 1, dtype: float64
# chapter 2
# par         0.630041
# theorem     0.168667
# force       0.165135
# network     0.161879
# hacker      0.159388
# alto        0.144310
# computer    0.136974
# citibank    0.135452
# defcon      0.124801
# machine     0.102871
# Name: 2, dtype: float64
# chapter 3
# par         0.772681
# theorem     0.171189
# kentucky    0.129372
# motel       0.128195
# '           0.094788
# agent       0.092146
# par's       0.087527
# nibbler     0.085450
# room        0.082428
# didn't      0.077937
# Name: 3, dtype: float64
# chapter 4
# phoenix     0.422049
# '           0.377926
# electron    0.323558
# computer    0.234113
# zardoz      0.232081
# deszip      0.214072
# machine     0.159961
# hacker      0.147157
# gandalf     0.121748
# password    0.106765
# Name: 4, dtype: float64
# chapter 5
# electron      0.441927
# phoenix       0.402399
# '             0.318567
# erik          0.159323
# computer      0.154732
# electron's    0.154109
# time          0.121359
# didn't        0.118325
# said          0.109223
# hacker        0.106189
# Name: 5, dtype: float64
# chapter 6
# pad         0.445743
# gandalf     0.301543
# hacker      0.238298
# wandii      0.233445
# computer    0.223247
# wandii's    0.143659
# police      0.137962
# judge       0.115812
# hacking     0.115386
# pad's       0.110547
# Name: 6, dtype: float64
# chapter 7
# mendax      0.550724
# computer    0.285920
# nortel      0.285335
# hacker      0.212473
# prime       0.154841
# trax        0.147587
# admin       0.145243
# suspect     0.132721
# nic         0.131450
# network     0.104925
# Name: 7, dtype: float64
# chapter 8
# mendax     0.529096
# prime      0.279763
# suspect    0.216591
# '          0.196913
# afp        0.192069
# police     0.169089
# hacker     0.156246
# court      0.151836
# judge      0.138348
# trax       0.136482
# Name: 8, dtype: float64
# chapter 9
# anthrax      0.794735
# x            0.133383
# anthrax's    0.121164
# patch        0.119876
# number       0.105781
# sniffer      0.100970
# computer     0.099434
# father       0.097552
# time         0.090972
# '            0.088856
# Name: 9, dtype: float64
# chapter 10
# anthrax      0.451229
# gutenberg    0.284321
# '            0.245142
# tm           0.214107
# computer     0.184884
# project      0.169382
# work         0.135582
# hacker       0.132842
# police       0.127364
# e            0.114700
# Name: 10, dtype: float64

# %% [markdown]
# ### Maths With Word Vectors
# So what we have now is a **vector** for each document (in our case, each document is a chapter). This vector represents something about the text in that chapter based on the frequencies that words occur, and how that relates to the corpus as a whole.
#
# We can use these vectors calculate how similar two documents by calculating the distance between them. Our vectors are currently >10,000. This means this is the _dimensionality_ of our vector. We can actually use similar maths that we would use to work out the distance between 2 points in 2 dimensional space. And its much easier to visualise how that works!
#
# Two methods often used are **Manhattan distance** and **Euclidean** distance, but we tend to use something else for TF/IDF vectors.
#
# ### Cosine Distance
#
# What we actually want to use is something called the **cosine distance**, which essentially tells how much the two vectors are pointing in the same direction. The results go from -1 to 1, where 1 is exactly the same, 0 is nothing in common and -1 is **anti-similar**. However, this never happens for TFIDF vectors, because word counts can never be negative!
#
# ### Similarity
#
# What we already see is that we can begin to group documents together by how similar they are. Later in the class we  will teach you some more advanced methods for taking this idea further.
#
# Interestingly, the first chapter seems to be the most different from the rest, and I think that isn't a Chapter per se, but the preface. Also, consecutive chapters tend to be the most simliar to each other.

# %%
#Import the cosine similarity method from sklearn
from sklearn.metrics.pairwise import cosine_similarity as cosine
result = cosine(tfidf_df)
#Put the result in a dataframe and 
df = pd.DataFrame(result)
#Show with heatmap style gradients
df.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_7b174_row0_col0, #T_7b174_row1_col1, #T_7b174_row2_col2, #T_7b174_row3_col3, #T_7b174_row4_col4, #T_7b174_row5_col5, #T_7b174_row6_col6, #T_7b174_row7_col7, #T_7b174_row8_col8, #T_7b174_row9_col9, #T_7b174_row10_col10 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7b174_row0_col1, #T_7b174_row2_col9, #T_7b174_row5_col9, #T_7b174_row8_col1, #T_7b174_row9_col7, #T_7b174_row10_col2, #T_7b174_row10_col3 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_7b174_row0_col2 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_7b174_row0_col3, #T_7b174_row6_col10, #T_7b174_row8_col10 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_7b174_row0_col4, #T_7b174_row0_col5, #T_7b174_row3_col1, #T_7b174_row3_col7, #T_7b174_row3_col9, #T_7b174_row3_col10, #T_7b174_row9_col0, #T_7b174_row9_col2, #T_7b174_row9_col3, #T_7b174_row9_col6, #T_7b174_row9_col8 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_7b174_row0_col6 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_7b174_row0_col7 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_7b174_row0_col8, #T_7b174_row0_col9, #T_7b174_row8_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_7b174_row0_col10, #T_7b174_row1_col0, #T_7b174_row1_col2 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_7b174_row1_col3 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_7b174_row1_col4, #T_7b174_row4_col2, #T_7b174_row6_col8, #T_7b174_row10_col8 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_7b174_row1_col5, #T_7b174_row10_col7 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_7b174_row1_col6, #T_7b174_row5_col8, #T_7b174_row10_col0 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_7b174_row1_col7 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_7b174_row1_col8, #T_7b174_row2_col6, #T_7b174_row4_col8 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_7b174_row1_col9, #T_7b174_row3_col4 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_7b174_row1_col10, #T_7b174_row3_col0, #T_7b174_row4_col3, #T_7b174_row6_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_7b174_row2_col0, #T_7b174_row10_col1 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_7b174_row2_col1, #T_7b174_row5_col2, #T_7b174_row7_col4 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_7b174_row2_col3 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_7b174_row2_col4 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_7b174_row2_col5 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_7b174_row2_col7 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_7b174_row2_col8, #T_7b174_row7_col5 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_7b174_row2_col10, #T_7b174_row6_col2, #T_7b174_row7_col2, #T_7b174_row8_col4 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_7b174_row3_col2 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_7b174_row3_col5, #T_7b174_row6_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_7b174_row3_col6, #T_7b174_row9_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_7b174_row3_col8, #T_7b174_row8_col0 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_7b174_row4_col0 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_7b174_row4_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_7b174_row4_col5 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_7b174_row4_col6 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_7b174_row4_col7 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_7b174_row4_col9, #T_7b174_row5_col7 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_7b174_row4_col10 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_7b174_row5_col0, #T_7b174_row6_col9, #T_7b174_row8_col3 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_7b174_row5_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_7b174_row5_col3, #T_7b174_row6_col7 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_7b174_row5_col4 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_7b174_row5_col6 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_7b174_row5_col10 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_7b174_row6_col3 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_7b174_row6_col4 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_7b174_row6_col5 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_7b174_row7_col0, #T_7b174_row9_col4 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_7b174_row7_col1 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_7b174_row7_col3, #T_7b174_row8_col9, #T_7b174_row9_col5 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_7b174_row7_col6 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_7b174_row7_col8, #T_7b174_row8_col7 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_7b174_row7_col9, #T_7b174_row7_col10 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_7b174_row8_col5 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_7b174_row8_col6 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_7b174_row9_col10 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_7b174_row10_col4, #T_7b174_row10_col6 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_7b174_row10_col5 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_7b174_row10_col9 {
#   background-color: #6ec173;
#   color: #000000;
# }
# </style>
# <table id="T_7b174">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b174_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7b174_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7b174_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_7b174_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_7b174_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_7b174_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_7b174_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_7b174_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_7b174_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_7b174_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_7b174_level0_col10" class="col_heading level0 col10" >10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b174_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b174_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7b174_row0_col1" class="data row0 col1" >0.256828</td>
#       <td id="T_7b174_row0_col2" class="data row0 col2" >0.295226</td>
#       <td id="T_7b174_row0_col3" class="data row0 col3" >0.289855</td>
#       <td id="T_7b174_row0_col4" class="data row0 col4" >0.189230</td>
#       <td id="T_7b174_row0_col5" class="data row0 col5" >0.183745</td>
#       <td id="T_7b174_row0_col6" class="data row0 col6" >0.209863</td>
#       <td id="T_7b174_row0_col7" class="data row0 col7" >0.176466</td>
#       <td id="T_7b174_row0_col8" class="data row0 col8" >0.164950</td>
#       <td id="T_7b174_row0_col9" class="data row0 col9" >0.147333</td>
#       <td id="T_7b174_row0_col10" class="data row0 col10" >0.302989</td>
#     </tr>
#     <tr>
#       <th id="T_7b174_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b174_row1_col0" class="data row1 col0" >0.256828</td>
#       <td id="T_7b174_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7b174_row1_col2" class="data row1 col2" >0.308646</td>
#       <td id="T_7b174_row1_col3" class="data row1 col3" >0.195964</td>
#       <td id="T_7b174_row1_col4" class="data row1 col4" >0.368159</td>
#       <td id="T_7b174_row1_col5" class="data row1 col5" >0.302507</td>
#       <td id="T_7b174_row1_col6" class="data row1 col6" >0.328194</td>
#       <td id="T_7b174_row1_col7" class="data row1 col7" >0.382442</td>
#       <td id="T_7b174_row1_col8" class="data row1 col8" >0.260568</td>
#       <td id="T_7b174_row1_col9" class="data row1 col9" >0.238328</td>
#       <td id="T_7b174_row1_col10" class="data row1 col10" >0.

# %% [markdown]
# ## Using TF/IDF to do a search
#
# Here we have a collection of **104** Tom Waits lyrics (https://www.kaggle.com/datasets/albertsuarez/azlyrics)
#
# We're going to show how you can use **TF/IDF** similarity to search for songs within it! As each TFIDF vector tells us something about the tokens present, and their importance to each song in relation to the wider catalogue, this will be a better search than simply matching exact strings.
#
# ### A Taylor Swift Aside
#
# Here we have a collection of **478** Taylor Swift lyrics (https://www.kaggle.com/datasets/deepshah16/song-lyrics-dataset
#
# Firstly, there is no way there are 478 Taylor Swift songs, most be some duplication.
#
# Also, although its given a song lyric dataset, whats actually in there?

# %%
taylor_swift = pd.read_csv("data/TaylorSwift.csv")
taylor_swift = taylor_swift[taylor_swift.notna()]

# %%
songs = taylor_swift[["Title","Lyric"]]

# %%
#Most are songs
songs.iloc[0]["Lyric"]
# Out:
# "vintage tee brand new phone high heels on cobblestones when you are young they assume you know\u2005nothing sequin\u2005smile black lipstick sensual\u2005politics when you are young they assume\u2005you know nothing   but i knew you dancin' in your levi's drunk under a streetlight i i knew you hand under my sweatshirt baby kiss it better i  refrain and when i felt like i was an old cardigan under someone's bed you put me on and said i was your favorite   a friend to all is a friend to none chase two girls lose the one when you are young they assume you know nothing   but i knew you playing hideandseek and giving me your weekends i i knew you your heartbeat on the high line once in twenty lifetimes i  refrain and when i felt like i was an old cardigan under someone's bed you put me on and said i was your favorite   to kiss in cars and downtown bars was all we needed you drew stars around my scars but now i'm bleedin'   'cause i knew you steppin' on the last train marked me like a bloodstain i i knew you tried to change the ending peter losing wendy i i knew you leavin' like a father running like water i and when you are young they assume you know nothing   but i knew you'd linger like a tattoo kiss i knew you'd haunt all of my whatifs the smell of smoke would hang around this long 'cause i knew everything when i was young i knew i'd curse you for the longest time chasin' shadows in the grocery line i knew you'd miss me once the thrill expired and you'd be standin' in my front porch light and i knew you'd come back to me you'd come back to me and you'd come back to me and you'd come back  refrain and when i felt like i was an old cardigan under someone's bed you put me on and said i was your favorite"

# %%
#Some are speeches
songs.iloc[439]["Lyric"]
# Out:
# 'im writing this post about the upcoming midterm elections on november 6th in which ill be voting in the state of tennessee in the past ive been reluctant to publicly voice my political opinions but due to several events in my life and in the world in the past two years i feel very differently about that now i always have and always will cast my vote based on which candidate will protect and fight for the human rights i believe we all deserve in this country i believe in the fight for lgbtq rights and that any form of discrimination based on sexual orientation or gender is wrong i believe that the systemic racism we still see in this country towards people of color is terrifying sickening and prevalent  i cannot vote for someone who will not be willing to fight for dignity for all americans no matter their skin color gender or who they love running for senate in the state of tennessee is a woman named marsha blackburn as much as i have in the past and would like to continue voting for women in office i cannot support marsha blackburn her voting record in congress appalls and terrifies me she voted against equal pay for women she voted against the reauthorization of the violence against women act which attempts to protect women from domestic violence stalking and date rape she believes businesses have a right to refuse service to gay couples she also believes they should not have the right to marry these are not my tennessee values i will be voting for phil bredesen for senate and jim cooper for house of representatives please please educate yourself on the candidates running in your state and vote based on who most closely represents your values for a lot of us we may never find a candidate or party with whom we agree 00 on every issue but we have to vote anyway  so many intelligent thoughtful selfpossessed people have turned 8 in the past two years and now have the right and privilege to make their vote count but first you need to register which is quick and easy to do october 9th is the last day to register to vote in the state of tn go to voteorg and you can find all the info happy voting'

# %%
#Some are not in english
songs.iloc[475]["Lyric"]
# Out:
# 'zwrotka  siedzę i patrzę jak czytasz z głową pochyloną budzę się i patrzę jakl oddychasz z zamkniętymi oczyma siedzę i oglądam ciebie zauważam wszystko co robisz i czego nie robisz jesteś tyle starszy i mądrzejszy i ja  refren  czekam przy drzwiach jak małe dziecko używam najlepsze farby na twój portret nakrywam stół wykwintnymi pierdołami i patrzę jak ty to jedynie znosisz jeśli to wszystko dzieje się w mojej głowie to powiedz mi teraz powiedz mi że mylę się jakoś wiem że moja miłość powinna być celebrowana a ty ją jedynie znosisz  zwrotka  witam cię jak zwycięzcę powracającego z pola walki pobłażliwie traktuję twoje niedyskrecje siedzę i słucham poleruję talеrze aż lśnią i błyszczą jesteś tylе starszy i mądrzejszy i ja  refren  czekam przy drzwiach jak małe dziecko używam najlepsze farby na twój portret nakrywam stół wykwintnymi pierdołami i patrzę jak ty to jedynie znosisz jeśli to wszystko dzieje się w mojej głowie to powiedz mi teraz powiedz mi że mylę się jakoś wiem że moja miłość powinna być celebrowana a ty ją jedynie znosisz   kiedy cię nie było  budowałeś inne światy gdzie byłam ja gdzie ten facet który rzucałby koce na mój drut kolczasty zrobiłam z ciebie moją świątynię mój mural moje niebo a teraz błagam o przypisy w historii twojego życia rysując serca w notce o autorze zawsze zabierałam ci za dużo miejsca i czasu zakładasz że u mnie wszystko gra ale co byś zrobił gdybym  refren  wyzwoliła sie i zostawiła cię w ruinach wzięła ten sztylet we mnie i go wyjęła zyskać twój ciężar a potem go stracić uwierz mi jestem w stanie to zrobić jeśli to wszystko dzieje się w mojej głowie to powiedz mi teraz powiedz mi że mylę się jakoś wiem że moja miłość powinna być celebrowana a ty ją jedynie znosisz   siedzę i oglądam cię'

# %%
#Some are lists of tour dates
songs.iloc[354]["Lyric"]
# Out:
# 'north america leg one5808  glendale az 508  santa clara ca 508  santa clara ca 5808  pasadena ca 5908  pasadena ca 508  seattle wa 5508  denver co 608  chicago il 608  chicago il europe6808  manchester england 6908  manchester england 6508  dublin ireland 6608  dublin ireland 608  london england 608  london england north america leg two6008  louisville ky 7708  columbus oh 7008  landover md 708  landover md 708  philadelphia pa 7408  philadelphia pa 7708  cleveland oh 7008  east rutherford nj 708  east rutherford nj 708  east rutherford nj 7608  foxborough ma 7708  foxborough ma 7808  foxborough ma 808  toronto canada 8408  toronto canada 8708  pittsburgh pa 8008  atlanta ga 808  atlanta ga 8408  tampa fl 8808  miami gardens fl 8508  nashville tn 8808  detroit mi 808  minneapolis mn 908  minneapolis mn 9808  kansas city mi 9508  indianapolis in 9808  st louis mi 908  new orleans la 9908  houston tx 0508  arlington tx 0608  arlington tx oceania0908  perth australia 0608  melbourne australia 08  sydney australia 608  brisbane australia 908  auckland nz asia008  tokyo japan 08  tokyo japan'

# %%
#Load in Tom Waits
tom_waits = pd.read_csv("data/tom_waits.tsv", delimiter="\t")
songs = tom_waits[["SONG_NAME","LYRICS"]]
songs.columns = ["Title","Lyric"]

# %%
songs.sample(10)
# Out:
#                                                 Title  \
# 49                                          that feel
# 94                                            kiss me
# 9   little trip to heaven (on the wings of your love)
# 62                                       big in japan
# 91                           what keeps mankind alive
# 54                                             nobody
# 14                                    kentuchy avenue
# 36                                       frank's song
# 17                               heartattack and vine
# 80                                lost in the harbour
#
#                                                 Lyric
# 49  well there's one thing you can't lose, it's th...
# 94  the fire's dying out, all the embers have been...
# 9   lazy trip to heaven on the wings of your love,...
# 62  i got the style but not the grace, i got the c...
# 91  you gentlemen who think you have a mission, to...
# 54  nobody, nobody, will ever love you the way i c...
# 14  eddie graces buick got 4 bullet holes in the s...
# 36  that woman will take you, that woman will brea...
# 17  liar liar with your pants on fire, white spade...
# 80  over here the ladies all want sweet perfume, b...

# %% [markdown]
# ### The Search
#
# 1. Get TFIDF vectors for all your documents (songs)
#
#
# 2. Use **the same** process to get a TFIDF vector for your query
#
#
# 3. Calculate cosine similarity
#
#
# 4. Return the nearest match(es)
#
#
# So now we can find songs that have **similar words** which are important in **similar ways**

# %%
#Use custom tokeniser
tfidf_vectoriser = TfidfVectorizer(tokenizer=my_tokeniser)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 #Use custom tokeniser
# ----> 2 tfidf_vectoriser = TfidfVectorizer(tokenizer=my_tokeniser)
#
# NameError: name 'my_tokeniser' is not defined

# %%
#Get TFIDF
tfidf = tfidf_vectoriser.fit_transform(songs["Lyric"])
#Save list of unique tokens (vocab) for later
vocab = tfidf_vectoriser.get_feature_names()
print(tfidf.todense().shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 #Get TFIDF
# ----> 2 tfidf = tfidf_vectoriser.fit_transform(songs["Lyric"])
#       3 #Save list of unique tokens (vocab) for later
#       4 vocab = tfidf_vectoriser.get_feature_names()
#
# NameError: name 'tfidf_vectoriser' is not defined

# %% [markdown]
# ### Most important terms for each song
#
# Interesting to see which songs the most important tokens are also the title. Not always the case!

# %%
tfidf_df = pd.DataFrame(tfidf.todense(), columns = vocab)
for i in range(len(tfidf_df)):
    print(songs.iloc[i]["Title"])
    print(tfidf_df.iloc[i].sort_values(ascending = False).head(10))
# Out:
# ol' 55
# truck      0.335463
# freeway    0.292749
# car        0.268395
# feeling    0.223642
# riding     0.215443
# sun's      0.197834
# went       0.194062
# luck       0.185340
# lady       0.185340
# coming     0.161037
# Name: 0, dtype: float64
# i hope that i don't fall in love with you
# hope      0.406561
# fall      0.310512
# love      0.303618
# don't     0.267786
# look      0.226836
# turn      0.186307
# chair     0.171597
# just      0.133893
# think     0.127423
# you're    0.108946
# Name: 1, dtype: float64
# virginia avenue
# catching    0.547334
# walking     0.273667
# tell        0.256617
# i'm         0.194285
# avenue      0.182445
# let         0.176979
# closing     0.170923
# dreaming    0.143162
# got         0.124384
# they're     0.123717
# Name: 2, dtype: float64
# old shoes (& picture postcards)
# kiss        0.324804
# dear        0.275953
# farewell    0.275953
# anymore     0.275953
# bind        0.275953
# gone        0.246205
# call        0.245008
# goodbye     0.245008
# eye         0.237111
# i'll        0.235342
# Name: 3, dtype: float64
# midnight lullaby
# dream         0.587640
# sixpence      0.206453
# rye           0.206453
# hush          0.206453
# bye           0.193415
# windowsill    0.193415
# mile          0.193415
# midnight      0.175039
# pocket        0.162001
# sing          0.162001
# Name: 4, dtype: float64
# martha
# martha      0.518879
# day         0.284116
# rainy       0.222377
# packed      0.222377
# poetry      0.222377
# sorrow      0.222377
# prose       0.222377
# tomorrow    0.204201
# saved       0.204201
# rose        0.160234
# Name: 5, dtype: float64
# rosie
# rosie         0.808743
# persuade      0.268599
# evade         0.268599
# tomcat        0.134300
# spree         0.134300
# melody        0.123323
# sitting       0.123323
# nobody's      0.115535
# lazy          0.115535
# windowsill    0.115535
# Name: 6, dtype: float64
# lonely
# lonely     0.981573
# eye        0.120035
# place      0.081520
# knew       0.062017
# thought    0.059221
# face       0.040760
# melanie    0.038033
# pain       0.034925
# love       0.033081
# jane       0.032719
# Name: 7, dtype: float64
# ice cream man
# good      0.462660
# cream     0.391575
# man       0.365854
# ice       0.354372
# i'm       0.267057
# yeah      0.231938
# band      0.208985
# i'll      0.203691
# honey     0.163988
# 'cause    0.141714
# Name: 8, dtype: float64
# little trip to heaven (on the wings of your love)
# it's        0.511741
# star        0.263695
# honey       0.234480
# heaven      0.219843
# da          0.216946
# thanking    0.199214
# trip        0.199214
# know        0.178692
# i've        0.177739
# you're      0.177739
# Name: 9, dtype: float64
# grapefruit moon
# shining       0.451031
# grapefruit    0.442570
# star          0.336211
# melody        0.304798
# moon          0.228646
# 'cause        0.206685
# hear          0.206685
# time          0.140418
# break         0.137790
# inside        0.137790
# Name: 10, dtype: float64
# new coat of paint
# let's          0.300855
# we'll          0.243687
# wear           0.236260
# shuffle        0.174860
# transfusion    0.174860
# knockin'       0.174860
# fishin'        0.174860
# scribbled      0.174860
# bloodshot      0.174860
# lovedreams     0.174860
# Name: 11, dtype: float64
# wrong side of the road
# em         0.205548
# we'll      0.183969
# you'll     0.178362
# catch      0.176011
# tear       0.168659
# tell       0.136400
# water      0.122646
# let        0.104522
# mamaand    0.088006
# mph        0.088006
# Name: 12, dtype: float64
# whistlin' past the graveyard
# steppin'         0.292140
# past             0.292140
# motherhubbard    0.292140
# crack            0.268262
# jack             0.268262
# papa             0.268262
# whistlin'        0.268262
# graveyard        0.238180
# mean             0.238180
# eyed             0.209434
# Name: 13, dtype: float64
# kentuchy avenue
# we'll     0.293926
# i'll      0.188764
# let       0.150294
# steal     0.145152
# string    0.137562
# mama      0.131361
# em        0.131361
# pocket    0.121576
# roof      0.117570
# tie       0.110745
# Name: 14, dtype: float64
# a sweet little bullet from a pretty blue gun
# pretty     0.374455
# dream      0.236852
# blue       0.236852
# sweet      0.233872
# it's       0.204040
# little     0.193841
# raining    0.187228
# pouring    0.187228
# gun        0.175404
# sign       0.158739
# Name: 15, dtype: float64
# blue valentines
# valentine    0.630113
# blue         0.320238
# sends        0.135518
# beneath      0.135518
# going        0.128432
# walk         0.128432
# baby         0.117932
# broken       0.106421
# it's         0.101341
# like         0.094806
# Name: 16, dtype: float64
# heartattack and vine
# heartattack    0.456448
# vine           0.419141
# you'll         0.246690
# line           0.190834
# liar           0.157069
# white          0.157069
# probably       0.157069
# pusher         0.091290
# philly         0.091290
# spade          0.091290
# Name: 17, dtype: float64
# saving all my love for you
# savin'           0.291083
# i'm              0.227710
# i'll             0.195390
# love             0.189887
# i'd              0.185949
# rumor            0.145541
# cadillacs        0.145541
# milkman          0.145541
# irresponsible    0.145541
# prostitute       0.145541
# Name: 18, dtype: float64
# downtown
# downtown    0.641355
# goin'       0.313736
# sugarman    0.256542
# pant        0.209157
# chivas      0.128271
# soldier     0.128271
# drinkin'    0.128271
# regal       0.128271
# temple      0.128271
# red         0.119808
# Name: 19, dtype: float64
# jersey girl
# la         0.935740
# sha        0.218363
# sing       0.078671
# cause      0.073760
# i'm        0.071176
# jersey     0.066839
# ride       0.059343
# tonight    0.054407
# don't      0.048859
# street     0.045324
# Name: 20, dtype: float64
# 'til the money runs out
# bye         0.740286
# baby        0.250530
# pint        0.143420
# head        0.085168
# can't       0.083302
# ain't       0.076851
# panther     0.071710
# martin's    0.071710
# eni         0.071710
# stitch      0.071710
# Name: 21, dtype: float64
# on the nickel
# nickel      0.562674
# sleepin'    0.229372
# boy         0.227974
# you'll      0.190063
# little      0.178311
# hole        0.135145
# just        0.125899
# they're     0.116789
# know        0.115865
# you're      0.102441
# Name: 22, dtype: float64
# frank's wild years (for frankie z.)
# frank        0.348845
# drove        0.247954
# mouth        0.174423
# station      0.174423
# used         0.151551
# little       0.144567
# home         0.110740
# payment      0.101376
# liquor       0.101376
# halloween    0.101376
# Name: 23, dtype: float64
# swordfishtrombones
# went                 0.274703
# deville              0.203312
# tenkiller            0.203312
# dirty                0.203312
# brougham             0.203312
# opened               0.203312
# butterfly            0.203312
# party                0.203312
# gee                  0.203312
# swordfishtrombone    0.203312
# Name: 24, dtype: float64
# down, down, down
# went        0.858673
# solid       0.267586
# boy         0.162624
# bathtub     0.133793
# cheatin'    0.133793
# chewed      0.133793
# tobacco     0.122858
# gin         0.115099
# told        0.109081
# lie         0.100006
# Name: 25, dtype: float64
# soldier's things
# tinker          0.238901
# soldier's       0.238901
# bravery         0.238901
# tailor          0.238901
# rifle           0.219375
# boot            0.219375
# rock            0.205521
# box             0.194775
# everything's    0.194775
# dollar          0.152614
# Name: 26, dtype: float64
# gin soaked boy
# soaked      0.382795
# gin         0.358621
# boy         0.337798
# know        0.228908
# don't       0.186549
# gonna       0.165034
# i'm         0.163055
# oklahoma    0.138956
# slipped     0.138956
# knittin'    0.138956
# Name: 27, dtype: float64
# trouble's braids
# trouble's    0.536673
# braid        0.536673
# pulled       0.492809
# old          0.111633
# mud          0.089144
# cold         0.076186
# road         0.069270
# spanked      0.059630
# swollen      0.059630
# seat         0.059630
# Name: 28, dtype: float64
# singapore
# singapore    0.303719
# sail         0.261282
# tonight      0.227020
# land         0.195961
# goodbye      0.185715
# boy          0.184583
# away         0.154189
# heave        0.151859
# nod          0.151859
# colored      0.151859
# Name: 29, dtype: float64
# clap hands
# clap           0.735168
# hand           0.482532
# roar           0.275688
# pole           0.091896
# sane           0.091896
# bitch          0.091896
# millionaire    0.091896
# window         0.083774
# comin'         0.079056
# son            0.079056
# Name: 30, dtype: float64
# cemetery polka
# uncle             0.642637
# vernon            0.311039
# shot              0.155519
# independent       0.155519
# accordion         0.155519
# slaughterhouse    0.155519
# wei               0.155519
# he's              0.145259
# hog               0.142808
# big               0.138530
# Name: 31, dtype: float64
# rockin' chair
# sittin'    0.454553
# money      0.298349
# rockin     0.272732
# right      0.264017
# chair      0.234625
# fly        0.212333
# woman      0.196517
# took       0.190042
# got        0.189712
# spend      0.181821
# Name: 32, dtype: float64
# midnight lullabye
# dream       0.514592
# sixpence    0.232443
# drop        0.232443
# sill        0.232443
# mile        0.217764
# midnight    0.197074
# pocket      0.182395
# sing        0.182395
# song        0.166145
# window      0.153840
# Name: 33, dtype: float64
# when you ain't got nobody
# look       0.346184
# feast      0.243532
# famine     0.243532
# bull       0.243532
# twice      0.243532
# anybody    0.243532
# hungry     0.209504
# nice       0.209504
# it's       0.208892
# stop       0.198550
# Name: 34, dtype: float64
# little trip to heaven
# it's        0.514154
# star        0.323813
# heaven      0.269964
# trip        0.244632
# lucky       0.217199
# i'm         0.208406
# know        0.164573
# face        0.142752
# nothing'    0.133203
# thank       0.133203
# Name: 35, dtype: float64
# frank's song
# woman      0.501828
# woman's    0.399704
# loose      0.299569
# gonna      0.258486
# frank      0.224677
# got        0.218002
# look       0.198003
# you're     0.190195
# mind       0.181985
# claw       0.174113
# Name: 36, dtype: float64
# look's like i'm up shit creek again
# shit       0.458455
# creek      0.420984
# look       0.260680
# morning    0.255564
# i'm        0.251050
# like       0.220732
# you've     0.214156
# lovin      0.183382
# can't      0.159770
# love       0.159505
# Name: 37, dtype: float64
# so long i'll see ya
# skat       0.497461
# skeet      0.497461
# outta      0.382663
# bye        0.329195
# buick's    0.191331
# waiting    0.191331
# gonna      0.159067
# cause      0.155109
# outside    0.148959
# gotta      0.119168
# Name: 38, dtype: float64
# earth died screaming
# died         0.389672
# screaming    0.365063
# earth        0.365063
# lay          0.237894
# dreaming     0.229328
# rained       0.212178
# big          0.125999
# sky          0.120646
# doesn't      0.106089
# trout        0.106089
# Name: 39, dtype: float64
# dirt in the ground
# we're      0.533216
# gonna      0.370668
# dirt       0.290800
# ground     0.216771
# groaned    0.178341
# just       0.159616
# stone      0.117055
# bone       0.105905
# dream      0.103585
# sky        0.101406
# Name: 40, dtype: float64
# such a scream
# scream    0.382978
# she's     0.344971
# steam     0.208160
# red       0.158982
# inside    0.158982
# queen     0.127659
# bien      0.127659
# fill      0.127659
# clay      0.127659
# donnie    0.127659
# Name: 41, dtype: float64
# in the colosseum
# colosseum    0.593036
# tonight      0.189975
# blame        0.169439
# senator      0.169439
# one's        0.155590
# family       0.155590
# men          0.155590
# it's         0.145338
# blood        0.118066
# princess     0.084719
# Name: 42, dtype: float64
# goin' out west
# i'm         0.341205
# gonna       0.310812
# west        0.300177
# goin'       0.284481
# got         0.182037
# hannibal    0.174466
# leash       0.174466
# 88          0.174466
# rex         0.174466
# speed       0.174466
# Name: 43, dtype: float64
# murder in the red barn
# murder    0.538787
# barn      0.538787
# red       0.365355
# farm      0.135402
# it's      0.096786
# thy       0.090268
# covet     0.090268
# spring    0.090268
# season    0.090268
# possum    0.090268
# Name: 44, dtype: float64
# black wings
# having    0.343643
# met       0.305108
# say       0.200530
# eye       0.196849
# fear      0.187115
# admire    0.187115
# risen     0.187115
# tooth     0.187115
# denies    0.187115
# he's      0.174770
# Name: 45, dtype: float64
# whistle down the wind
# wind        0.232208
# i've        0.218358
# i'm         0.208499
# stay        0.180057
# i'd         0.170261
# red         0.165961
# place       0.142816
# windmill    0.133263
# clock's     0.133263
# cursed      0.133263
# Name: 46, dtype: float64
# i don't wanna grow up
# wanna      0.763580
# don't      0.415257
# grow       0.376927
# thing      0.071876
# nothin'    0.060314
# live       0.060314
# old        0.056647
# stay       0.054512
# fall       0.050245
# hair       0.050245
# Name: 47, dtype: float64
# let me get up on it
# c'mon       0.859822
# let         0.510594
#             0.000000
# rainbow     0.000000
# rafter      0.000000
# rag         0.000000
# rage        0.000000
# rail        0.000000
# railraod    0.000000
# railroad    0.000000
# Name: 48, dtype: float64
# that feel
# feel       0.491161
# lose       0.410485
# it's       0.302307
# leave      0.244790
# thing      0.239188
# can't      0.233948
# there's    0.182909
# throw      0.156792
# altar      0.100696
# find       0.100696
# Name: 49, dtype: float64
# hope i don't fall in love with you
# hope      0.450701
# fall      0.344224
# love      0.336582
# don't     0.247383
# chair     0.190227
# look      0.188598
# just      0.148430
# think     0.141257
# you're    0.120774
# make      0.114240
# Name: 50, dtype: float64
# mockin' bird
# mocking    0.819131
# bird       0.387194
# high       0.170019
# looking    0.167151
# you're     0.149132
# singing    0.131161
# song       0.119476
# tree       0.108095
# gone       0.099422
# note       0.091015
# Name: 51, dtype: float64
# in between love
# love       0.738029
# scheme     0.377114
# trying     0.307459
# thought    0.220199
# breezy     0.188557
# easy       0.188557
# cool       0.153729
# woman      0.135865
# tell       0.097415
# sublime    0.094278
# Name: 52, dtype: float64
# blue skies
# blue       0.423989
# sky        0.415069
# woman      0.350657
# reason     0.313990
# shine      0.284158
# place      0.260769
# bed        0.254327
# head       0.216743
# face       0.195577
# cubards    0.121663
# Name: 53, dtype: float64
# nobody
# strong         0.623601
# cause          0.458784
# love           0.393790
# nobody's       0.292109
# way            0.225958
# bittersweet    0.113184
# treasure       0.103933
# lover          0.103933
# life's         0.097370
# deep           0.097370
# Name: 54, dtype: float64
# i want you
# want         0.891753
# brightest    0.277366
# day          0.177186
# sun          0.177186
# star         0.168568
# say          0.148625
# love         0.120626
# rain         0.000000
# rafter       0.000000
# rag          0.000000
# Name: 55, dtype: float64
# shiver me timbers
# i'm         0.316829
# leavin'     0.270474
# timber      0.220911
# shiver      0.220911
# sailin'     0.220911
# 'cause      0.183410
# shiftin'    0.147274
# daughter    0.147274
# liftin'     0.147274
# sand's      0.147274
# Name: 56, dtype: float64
# diamonds on my windshield
# last'           0.324393
# 'home           0.324393
# whisper         0.324393
# pulling         0.194636
# sing            0.140245
# late            0.140245
# steel           0.129757
# east            0.129757
# welldigger's    0.129757
# interstate      0.129757
# Name: 57, dtype: float64
# please call me, baby
# we're      0.279500
# admit      0.249286
# angel      0.228911
# walking    0.228911
# crazy      0.228911
# leave      0.227253
# you'd      0.203241
# wish       0.173704
# god        0.168410
# just       0.167334
# Name: 58, dtype: float64
# so it goes
# sky        0.475801
# wind       0.324018
# blowin     0.278928
# seagull    0.278928
# pain       0.256130
# fortune    0.256130
# know       0.229745
# blow       0.200982
# go         0.194360
# i'd        0.178184
# Name: 59, dtype: float64
# old shoes
# dear        0.334694
# anymore     0.267755
# farewell    0.267755
# bind        0.267755
# kiss        0.262630
# gone        0.238891
# call        0.237730
# goodbye     0.237730
# eye         0.230067
# i'll        0.195729
# Name: 60, dtype: float64
# the last rose of summer
# garden      0.373931
# summer      0.331999
# rose        0.293419
# winter      0.203607
# carrying    0.203607
# petal       0.203607
# tattered    0.203607
# favorite    0.186966
# taking      0.175158
# shadow      0.166000
# Name: 61, dtype: float64
# big in japan
# japan     0.599477
# got       0.536137
# big       0.355991
# heh       0.256919
# i'm       0.234481
# ebb       0.085640
# cheese    0.085640
# bread     0.085640
# nation    0.078640
# ho        0.078640
# Name: 62, dtype: float64
# lowside of the road
# rollin     0.544145
# lowside    0.395052
# you're     0.269714
# road       0.229457
# she's      0.133443
# man        0.105843
# load       0.098763
# flapper    0.098763
# kokomo     0.098763
# rise       0.098763
# Name: 63, dtype: float64
# hold on
# hung        0.547526
# sign        0.522844
# live        0.501976
# town        0.418174
#             0.000000
# rainbow     0.000000
# rag         0.000000
# rage        0.000000
# rail        0.000000
# railraod    0.000000
# Name: 64, dtype: float64
# get behind the mule
# mule        0.470969
# plow        0.432475
# morning     0.328175
# got         0.196563
# lord        0.143992
# noose       0.117742
# brandy      0.117742
# stirring    0.117742
# lookin      0.117742
# jack        0.108119
# Name: 65, dtype: float64
# house where nobody lives
# house        0.528602
# did          0.417090
# held         0.265563
# life         0.215101
# laughter     0.154347
# trade        0.141732
# cracked      0.141732
# someone's    0.141732
# somebody     0.141732
# mean         0.125839
# Name: 66, dtype: float64
# cold water
# cold        0.446316
# water       0.405693
# cool        0.284807
# friendly    0.250433
# woke        0.213852
# look        0.198631
# ain't       0.187187
# morning     0.162277
# don't       0.156326
# money       0.152857
# Name: 67, dtype: float64
# pony
# pony       0.688338
# hope       0.561198
# home       0.156650
# belzoni    0.114723
# way        0.114515
# nothin     0.105346
# know       0.094494
# blind      0.071436
# i've       0.062660
# worked     0.057361
# Name: 68, dtype: float64
# what's he building?
# building    0.723939
# what's      0.422713
# he's        0.187827
# heard       0.122268
# hell        0.105121
# saw         0.103798
# friend      0.093936
# child       0.081512
# light       0.077078
# mayor       0.060328
# Name: 69, dtype: float64
# black market baby
# she's      0.540958
# market     0.369574
# coal       0.351530
# black      0.291285
# stay       0.249673
# want       0.198034
# baby       0.184452
# diamond    0.128761
# prayer     0.100437
# way        0.092226
# Name: 70, dtype: float64
# eyeball kid
# hail       0.400743
# kid        0.314458
# people     0.187718
# eyeball    0.177902
# child      0.147414
# time       0.138464
# got        0.136606
# can't      0.126740
# that's     0.124073
# said       0.112733
# Name: 71, dtype: float64
# picture in a frame
# come       0.440787
# picture    0.365654
# frame      0.365654
# sunday     0.298115
# calling    0.284677
# best       0.273315
# gold       0.263472
# sun        0.233586
# blue       0.212381
# love       0.212030
# Name: 72, dtype: float64
# chocolate jesus
# jesus        0.544266
# chocolate    0.518622
# got          0.216452
# it's         0.190652
# good         0.172131
# don't        0.165774
# satisfied    0.136066
# knee         0.127474
# sunday       0.120808
# better       0.110758
# Name: 73, dtype: float64
# georgia lee
# wasn't       0.576801
# god          0.452959
# georgia      0.372491
# listening    0.223495
# lee          0.223495
# watching     0.192267
# hard         0.107360
# play         0.103822
# dropping     0.074498
# doing        0.074498
# Name: 74, dtype: float64
# flowers grave
# flower's     0.376634
# dreamland    0.324009
# flower       0.324009
# grave        0.307068
# shower       0.282476
# rose         0.271384
# put          0.259388
# die          0.254443
# tonight      0.211142
# ahead        0.188317
# Name: 75, dtype: float64
# no one knows i'm gone
# gone      0.350689
# bury      0.348984
# leaf      0.348984
# year      0.308429
# bathe     0.214023
# john      0.214023
# lovely    0.214023
# golden    0.184119
# know      0.176285
# sound     0.174492
# Name: 76, dtype: float64
# kommienezuspadt
# kommienezuspadt    0.648736
# ha                 0.504572
# sei                0.288327
# punktlich          0.288327
# late               0.259693
# kommiene           0.216245
# can't              0.209335
#                    0.016128
# raining            0.000000
# rained             0.000000
# Name: 77, dtype: float64
# poor edward
# edward      0.460244
# face        0.246620
# poor        0.238880
# took        0.213801
# hell        0.178215
# remove      0.153415
# freed       0.153415
# doom        0.153415
# twin        0.153415
# separate    0.153415
# Name: 78, dtype: float64
# table top joe
# tabletop    0.692602
# joe         0.517698
# yeah        0.169402
# famous      0.138520
# body        0.119166
# singing     0.099811
# born        0.096522
# hand        0.090919
# day         0.088489
# i'd         0.088489
# Name: 79, dtype: float64
# lost in the harbour
# harbour       0.720722
# wool          0.220605
# come          0.186174
# rose          0.173106
# tear          0.153470
# they're       0.149594
# lost          0.136602
# want          0.128732
# frightened    0.120120
# weaving       0.120120
# Name: 80, dtype: float64
# we're all mad here
# we're          0.328342
# mad            0.251930
# die            0.197839
# bone           0.173904
# face           0.156921
# shaped         0.146424
# flag           0.146424
# decomposing    0.146424
# rugged         0.146424
# judd           0.146424
# Name: 81, dtype: float64
# watch her disappear
# watched        0.467319
# disappeared    0.373855
# light          0.238825
# yellow         0.228602
# air            0.171649
# black          0.126283
# hair           0.116397
# hear           0.116397
# moving         0.093464
# orchid         0.093464
# Name: 82, dtype: float64
# reeperbahn
# reeperbahn    0.565437
# bright        0.188479
# oh            0.180605
# father        0.173074
# cheek         0.173074
# you've        0.146739
# red           0.117363
# you're        0.102944
# said          0.097374
# comedian      0.094239
# Name: 83, dtype: float64
# i'm still here
# haven't    0.556611
# looked     0.433345
# year       0.401067
# way        0.277801
# pond       0.170373
# til        0.170373
# stopped    0.151267
# wanted     0.144448
# clear      0.144448
# dreamed    0.144448
# Name: 84, dtype: float64
# fish & bird
# live       0.366720
# 'you       0.245308
# pretend    0.245308
# whale      0.245308
# i'll       0.219552
# sail       0.211033
# promise    0.199998
# dry        0.183360
# hold       0.183360
# wait       0.183360
# Name: 85, dtype: float64
# barcarolle
# belong     0.293845
# branch     0.269828
# grass      0.252787
# train      0.211730
# spell      0.146922
# blond      0.146922
# filling    0.146922
# skating    0.146922
# knit       0.146922
# kissed     0.146922
# Name: 86, dtype: float64
# misery is the river of the world
# everybody    0.475226
# misery's     0.475226
# row          0.436384
# river        0.355216
# world        0.315456
# there's      0.092488
# lost         0.077205
# man          0.072756
# want         0.072756
# dy           0.067889
# Name: 87, dtype: float64
# fish in the jailhouse
# jailhouse    0.578123
# fish         0.497345
# serving      0.375780
# tonight      0.345703
# they're      0.233992
# right        0.151105
# oh           0.129260
# boy          0.122973
# fishbone     0.057812
# new          0.035999
# Name: 88, dtype: float64
# bottom of the world
# lost          0.544655
# i'm           0.524535
# world         0.278181
# bishop        0.239470
# barbershop    0.239470
# handcuffed    0.219897
# liar          0.206010
# hair          0.059645
# satchel       0.047894
# birdy         0.047894
# Name: 89, dtype: float64
# lucinda
# lucinda     0.407303
# i'll        0.243025
# heaven      0.183441
# thought     0.158551
# home        0.148309
# did         0.137581
# pleaser     0.135768
# opium       0.135768
# firework    0.135768
# tar         0.135768
# Name: 90, dtype: float64
# what keeps mankind alive
# alive        0.405962
# mankind      0.405962
# fact         0.221048
# food         0.202981
# keep         0.190162
# start        0.172095
# oppressed    0.110524
# sort         0.110524
# position     0.110524
# bestial      0.110524
# Name: 91, dtype: float64
# children's story
# earth     0.365581
# wanted    0.220565
# moon      0.219547
# night     0.208597
# went      0.191393
# child     0.191393
# sun       0.180980
# day       0.180980
# got       0.177360
# dead      0.176409
# Name: 92, dtype: float64
# heigh ho! (the dwarfs' marching song)
# dig        0.891141
# heigh      0.298603
# ho         0.274197
# day        0.095376
# got        0.062312
# singing    0.053790
# diamond    0.052017
# long       0.043359
# trick      0.037325
# sight      0.037325
# Name: 93, dtype: float64
# kiss me
# kiss        0.552540
# stranger    0.477608
# want        0.410902
# like        0.246137
# believe     0.238804
# mystery     0.153366
# love's      0.153366
# sin         0.119402
# look        0.087205
# wore        0.076683
# Name: 94, dtype: float64
# satisfied
# satisfaction    0.488011
# i'm             0.439029
# gone            0.373162
# barrel          0.293877
# let             0.260819
# bullet          0.251895
# satisfied       0.224062
# mr              0.145909
# said            0.126061
# jagger          0.097602
# Name: 95, dtype: float64
# last leaf
# leaf        0.568973
# tree        0.497308
# autumn      0.320417
# i'm         0.300266
# rest        0.240146
# took        0.194514
# won't       0.137416
# fight       0.108665
# i've        0.076234
# eternity    0.069787
# Name: 96, dtype: float64
# hell broke luce
# left        0.506455
# luce        0.426426
# broke       0.382429
# hell        0.272448
# right       0.247680
# home        0.139745
# scorched    0.085285
# march       0.085285
# chef        0.085285
# sergio's    0.085285
# Name: 97, dtype: float64
# new year's eve
# auld            0.454861
# acquaintance    0.303241
# forgot          0.303241
# like            0.152084
# lang            0.151620
# started         0.151620
# felt            0.151620
# syne            0.151620
# sake            0.151620
# brought         0.139228
# Name: 98, dtype: float64
# she stole the blush
# blush      0.250564
# chose      0.250564
# cheater    0.250564
# drown      0.230085
# stole      0.230085
# long       0.218302
# wanna      0.215554
# fly        0.195075
# honey      0.180544
# rose       0.180544
# Name: 99, dtype: float64
# tell me
# tell       0.565372
# won't      0.331513
# cover      0.252540
# dust       0.231899
# drown      0.231899
# highway    0.231899
# doe        0.205894
# river      0.188766
# blow       0.181968
# sun        0.161327
# Name: 100, dtype: float64
# after you die
# like        0.836954
# feeding     0.139067
# tin         0.127700
# that's      0.118611
# die         0.093949
# big         0.082583
# tramp       0.069533
# softie      0.069533
# tweaking    0.069533
# pig         0.069533
# Name: 101, dtype: float64
# back in the good old world (gypsy)
# good         0.211048
# world        0.211048
# gone         0.198460
# october's    0.181679
# winding      0.181679
# chance       0.181679
# rag          0.181679
# got's        0.181679
# edge         0.181679
# upside       0.181679
# Name: 102, dtype: float64
# cold cold ground (live)
# cold       0.795103
# ground     0.378214
# til        0.095243
# rope       0.095243
# there's    0.094202
# dream      0.090366
# tire       0.089228
# box        0.084563
# we'll      0.072273
# bring      0.070071
# Name: 103, dtype: float64

# %% [markdown]
# ### Conducting a query

# %%
#Get the TFIDF vector for your query
query = tfidf_vectoriser.transform(["a drunk man beer wine whiskey"])

# %%
#Get similarity between query and song catalogue
similarity = cosine(query.todense(), tfidf.todense())[0]
# Out:
# /Users/louisbusby/opt/miniconda3/envs/tf_m1/lib/python3.9/site-packages/sklearn/utils/validation.py:727: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# /Users/louisbusby/opt/miniconda3/envs/tf_m1/lib/python3.9/site-packages/sklearn/utils/validation.py:727: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(

# %%
#Get the closest 5 songs
closest = np.argsort(similarity, )[-5:]
songs.iloc[closest].values
# Out:
# array([["i hope that i don't fall in love with you",
#         "well i hope that i don't fall in love with you, 'cause falling in love just makes me blue, well the music plays and you display your heart for me to see, i had a beer and now i hear you calling out for me, and i hope that i don't fall in love with you. well the room is crowded, people everywhere, and i wonder, should i offer you a chair?, well if you sit down with this old clown, take that frown and break it, before the evening's gone away, i think that we could make it, and i hope that i don't fall in love with you. well the night does funny things inside a man, these old tom-cat feelings you don't understand, well i turn around to look at you, you light a cigarette, i wish i had the guts to bum one, but we've never met, and i hope that i don't fall in love with you. i can see that you are lonesome just like me, and it being late, you'd like some some company, well i turn around to look at you, and you look back at me, the guy you're with has up and split, the chair next to you's free, and i hope that you don't fall in love with me. now it's closing time, the music's fading out, last call for drinks, i'll have another stout. well i turn around to look at you, you're nowhere to be found, i search the place for your lost face, guess i'll have another round, and i think that i just fell in love with you."],
#        ['heartattack and vine',
#         "liar liar with your pants on fire, white spades hangin' on the telephone, wire, gamblers reevaluate along the dotted line, you'll never recognize, yourself on heartattack and vine. doctor lawyer beggar man thief, philly joe remarkable looks on in disbelief, if you want a taste of madness, you'll have to wait in line, you'll probably, see someone you know on heartattack and vine. boney's high on china white, shorty found a punk, don't you know there ain't, no devil, there's just god when he's drunk, well this stuff will probably kill, you, let's do another line, what you say you meet me down on heartattack and, vine. see that little jersey girl in the see-through top, with the peddle pushers, sucking on a soda pop, well i bet she's still a virgin but it's only twenty-, five 'til nine, you can see a million of 'em on heartattack and vine. better off in iowa against your scrambled eggs, than crawling down cahuenga, on a broken pair of legs, you'll find your ignorance is blissful every goddamn, time, your're waitin' for the rtd on heartattack and vine."],
#        ['new coat of paint',
#         "let's put a new coat of paint on this lonesome old town, set 'em up, we'll be knockin' em down. you wear a dress, baby, and i'll wear a tie. we'll laugh at that old bloodshot moon in that burgundy sky, all your scribbled lovedreams, are lost or thrown away, here amidst the shuffle of an overflowing day, our love needs a transfusion so let's shoot it full of wine, fishin' for a good time starts with throwin'in your line."],
#        ['barcarolle',
#         "a cloud lets go of the moon, her ribbons are all out of tune, she is skating on the ice, in a glass in the hands of a man, that she kissed on a train, and the children are all gone into town, to get candy and we are alone in the house here, and your eyes fall down on me, and i belong only to you, the water is filling my shoes, in the wine of my heart there's a stone, in a well made of bone, that you bring to the pond, and i'm here in your pocket, curled up in a dollar, and the chain from your watch around my neck, and i'll stay right here until it's time, the girls all knit in the shade, before the baby is made, and the branches bend down, to the ground here to swing on, i'm lost in the blond summer grass, and the train whistle blows, and the carnival goes, till there's only the tickets and crows here, and the grass will all grow back, and the branches spell 'alice', and i belong only to you"],
#        ['ice cream man',
#         "i'll be clickin' by your house about two forty-five, sidewalk sundae strawberry surprise, i got a cherry popsicle right on time, a big stick, mamma, that'll blow your mind, 'cause i'm the ice cream man, i'm a one-man band, i'm the ice cream man, honey, i'll be good to you. baby, missed me in the alley, baby, don't you fret, come back around and don't forget, when you're tired and you're hungry and you want something cool, got something better than a swimming pool, 'cause i'm the ice cream man, i'm a one-man band, i'm the ice cream man, honey, i'll be good to you. 'cause i'm the ice cream man, i'm a one-man band, i'm the ice cream man, honey, i'll be good to you. see me coming, you ain't got no change, don't worry baby, it can be arranged: show me you can smile, baby just for me, fix you with a drumstick, i'll do it for free, 'cause i'm the ice cream man, i'm a one-man band, i'm the ice cream man, honey, i'll be good to you. be good to you, be good to you, good to you yeah, good to you yeah, good to you yeah, good to you yeah, good to you yeah, good to you, i'll be good to you, i'll be good to you."]],
#       dtype=object)

# %% [markdown]
# ### LSA
#
# Texts the say the same things, but with different words, will have completely different TFIDF vectors. We can do better!
#
# Topic Modelling approaches attempt to improve this can grouping things together based on similar semantic meaning, not just frequency of terms.
#
# SVD will group together terms that occur frequently together in the same documents
#
# The first thing we need to do is subtract the mean of each tfidf column from each value (sometimes called "whitening")

# %%
from sklearn.decomposition import TruncatedSVD

# %%
lyrics = pd.read_csv("data/lyric_data.tsv", delimiter="\t")
songs = lyrics[["ARTIST_NAME-SONG_NAME","LYRICS"]]
songs.columns = ["Title","Lyric"]

# %%
lyrics.columns
# Out:
# Index(['ARTIST_NAME-SONG_NAME', 'ARTIST_URL', 'SONG_NAME', 'SONG_URL',
#        'LYRICS'],
#       dtype='object')

# %%
#Get TFIDF
tfidf = tfidf_vectoriser.fit_transform(songs["Lyric"])
#Save list of unique tokens (vocab) for later
vocab = tfidf_vectoriser.get_feature_names_out()
tfidf_df = pd.DataFrame(tfidf.todense(), columns = vocab)
print(tfidf.todense().shape)
# Out:
# (1636, 12319)

# %%
#Subtract mean
tfidf_df = tfidf_df - tfidf_df.mean()

# %%
#How many topics?
num_topics = 16
pd.options.display.max_columns=num_topics
labels = ['topic{}'.format(i) for i in range(num_topics)]

# %%
#Calculate topics
svd = TruncatedSVD(n_components = num_topics, n_iter = 100) 
svd_topic_vectors = svd.fit_transform(tfidf_df.values)

# %% [markdown]
# Now we have 16 values for each song (instead of 1000s!)
#
# But there's more!
#
# We can look at the weights LSA has assigned to each word within each topic. `svd.components_` is a variable that gives us these weightings:

# %%
#How much does each topic apply to each token?
topic_weights = pd.DataFrame(svd.components_.T, index=vocab, columns=labels)
topic_weights.sample(20) #display it
# Out:
#                  topic0    topic1    topic2        topic3    topic4    topic5  \
# wailing       -0.001008 -0.000168  0.000279 -9.846614e-04  0.000017 -0.000893
# savior         0.000037 -0.000098 -0.000617 -5.234750e-04 -0.000027  0.000926
# split          0.000526  0.007128 -0.003817  8.617967e-04  0.001127 -0.004547
# media's        0.000344  0.001593  0.000117  5.331844e-04  0.001602  0.000252
# carbon        -0.000308  0.000072 -0.001240  1.182744e-03  0.000618 -0.000115
# flower's      -0.002208  0.002256  0.001929 -1.971360e-03 -0.000399 -0.000486
# v             -0.000515 -0.000431 -0.000808 -8.686411e-04 -0.000636  0.001153
# platform      -0.000419  0.000295 -0.001237  4.140290e-04 -0.000129 -0.000800
# chemistry     -0.000080 -0.000506 -0.000070 -1.105099e-03 -0.000395  0.000536
# grey          -0.006863  0.006509 -0.002223 -1.534188e-03 -0.006659 -0.010944
# finish         0.000845  0.001713 -0.002264  2.002604e-03  0.000810 -0.000613
# rain)         -0.000404 -0.000031  0.000281 -1.742825e-04 -0.000002  0.000158
# toos           0.000588  0.001187  0.000780 -5.295514e-04  0.001037  0.000887
# filed         -0.000096  0.000094 -0.000156 -7.267057e-07 -0.000649  0.000048
# angeline      -0.001969 -0.000248  0.001556 -3.654685e-03  0.001711 -0.000210
# blow           0.002773 -0.001722  0.000841  3.387977e-03  0.012340  0.001777
# hjortum       -0.000499  0.000069  0.000261 -2.454759e-04 -0.000133 -0.000223
# howlin'        0.000361 -0.001375 -0.000132  1.278451e-04  0.001200  0.000958
# unconditional  0.000691  0.000578 -0.001387  1.260102e-03  0.000547  0.000113
# amazin'       -0.000111 -0.000307 -0.000737  5.098223e-04  0.000106  0.000239
#
#                  topic6    topic7    topic8    topic9   topic10   topic11  \
# wailing        0.000861 -0.000575  0.000353 -0.000170  0.000469 -0.000980
# savior        -0.000692 -0.001461 -0.000917 -0.000691 -0.000992 -0.000301
# split          0.002331  0.000140 -0.004852 -0.001048 -0.002901 -0.004172
# media's        0.000342  0.001136  0.002887  0.000629 -0.000152 -0.000334
# carbon         0.000162 -0.000779  0.000490 -0.000365 -0.001258  0.000180
# flower's      -0.000207  0.001419  0.001120  0.000195  0.000186  0.000882
# v             -0.001213  0.000610  0.000084 -0.001338 -0.001595 -0.001015
# platform       0.000605  0.000127  0.000859 -0.000359 -0.000063  0.000374
# chemistry      0.000130  0.000045  0.000175 -0.000415 -0.000680 -0.000987
# grey          -0.000254 -0.003208 -0.004220 -0.001393 -0.003155  0.008333
# finish        -0.001779  0.002285 -0.001213  0.000374  0.004223 -0.001249
# rain)          0.000164  0.000047  0.000265  0.000042 -0.000102  0.000263
# toos           0.000463  0.000526 -0.000413 -0.000174  0.001016 -0.000507
# filed         -0.000779  0.000475  0.000229  0.000004  0.000481  0.000769
# angeline       0.003282  0.000157  0.008040 -0.001994  0.001608 -0.002703
# blow          -0.001354 -0.005511  0.009914 -0.009435  0.002436  0.005407
# hjortum        0.000035  0.000002  0.000238 -0.000079 -0.000012  0.000302
# howlin'        0.002566 -0.000146 -0.001989 -0.000813 -0.002668  0.002127
# unconditional  0.000165  0.001453  0.000794  0.000152 -0.000040 -0.000293
# amazin'        0.000608  0.000639  0.000766 -0.000107 -0.000306 -0.000301
#
#                 topic12   topic13   topic14   topic15
# wailing        0.000424 -0.000062  0.000280  0.000573
# savior         0.001340 -0.000456  0.000528  0.000446
# split         -0.002121  0.009345 -0.005379  0.000740
# media's        0.000190  0.000465  0.000677 -0.000409
# carbon         0.001080  0.000070 -0.000781  0.000929
# flower's      -0.001624 -0.000590  0.000019 -0.003147
# v             -0.000071 -0.000320 -0.001224 -0.001070
# platform       0.000531  0.000332 -0.001552  0.000827
# chemistry     -0.001227  0.001584 -0.000146 -0.001033
# grey          -0.005100  0.001660 -0.003012  0.003724
# finish        -0.002711 -0.001230 -0.004778  0.000253
# rain)         -0.000014 -0.000216  0.000283 -0.000311
# toos          -0.000279  0.000999 -0.000304 -0.000480
# filed          0.000349 -0.000820 -0.001774 -0.001508
# angeline       0.005351 -0.002153 -0.000696  0.000026
# blow           0.001747 -0.005916 -0.004119 -0.000018
# hjortum       -0.000186 -0.000134  0.000188 -0.000083
# howlin'        0.000697 -0.000704 -0.000877 -0.000405
# unconditional -0.001012  0.000027 -0.000270  0.000569
# amazin'        0.000706 -0.000519  0.000442 -0.000331

# %%
#How much does each topic apply to each song?
svd_topic_vectors_df = pd.DataFrame(svd_topic_vectors, index=songs["Title"].values, columns=labels)
svd_topic_vectors_df.sample(10)
# Out:
#                                                 topic0    topic1    topic2  \
# britney spears-plastic                        0.009118 -0.071823 -0.084237
# waits, tom-blue valentines                   -0.005124  0.006600 -0.033510
# elton john-i don't care                       0.094584  0.017630 -0.114931
# beach boys-the little old lady from pasadena -0.092713 -0.000648 -0.004298
# waits, tom-she stole the blush               -0.059362  0.016893 -0.003358
# aerosmith-love in an elevator                 0.087333  0.131247  0.034533
# aerosmith-deuces are wild                     0.152323  0.122794  0.025325
# depeche mode-a pain that i'm used to          0.094769  0.012326 -0.205065
# eddie vedder-goodbye                          0.054795  0.108312 -0.098280
# spice girls-love thing                        0.359084  0.060980 -0.203730
#
#                                                 topic3    topic4    topic5  \
# britney spears-plastic                       -0.044189 -0.078905  0.061279
# waits, tom-blue valentines                    0.006746  0.064683 -0.062322
# elton john-i don't care                      -0.077113  0.006914  0.211456
# beach boys-the little old lady from pasadena -0.000978  0.063456  0.019759
# waits, tom-she stole the blush               -0.027765 -0.044169 -0.007880
# aerosmith-love in an elevator                 0.030594  0.138934  0.073553
# aerosmith-deuces are wild                    -0.035696  0.118066  0.053187
# depeche mode-a pain that i'm used to          0.088134 -0.008940 -0.023979
# eddie vedder-goodbye                          0.037851 -0.055692 -0.054634
# spice girls-love thing                        0.013284 -0.032231  0.198995
#
#                                                 topic6    topic7    topic8  \
# britney spears-plastic                        0.102349 -0.012192  0.064009
# waits, tom-blue valentines                    0.006534 -0.026172 -0.019424
# elton john-i don't care                      -0.041294 -0.232806  0.118562
# beach boys-the little old lady from pasadena -0.051334 -0.055528 -0.057713
# waits, tom-she stole the blush                0.012088  0.034496  0.006408
# aerosmith-love in an elevator                 0.013081  0.060507  0.132390
# aerosmith-deuces are wild                     0.024164 -0.002985 -0.039618
# depeche mode-a pain that i'm used to          0.022430 -0.013775  0.012572
# eddie vedder-goodbye                         -0.016587 -0.024897 -0.008595
# spice girls-love thing                       -0.060752  0.025150  0.086975
#
#                                                 topic9   topic10   topic11  \
# britney spears-plastic                       -0.063900 -0.042260  0.017785
# waits, tom-blue valentines                    0.031939 -0.046856 -0.048682
# elton john-i don't care                      -0.095481 -0.247927 -0.030415
# beach boys-the little old lady from pasadena -0.054845  0.044815 -0.047933
# waits, tom-she stole the blush               -0.011582 -0.038955 -0.031950
# aerosmith-love in an elevator                -0.011199 -0.026513 -0.035667
# aerosmith-deuces are wild                    -0.068937  0.065999 -0.079658
# depeche mode-a pain that i'm used to          0.117372  0.012976 -0.055514
# eddie vedder-goodbye                          0.018890 -0.024555  0.062336
# spice girls-love thing                        0.006633 -0.044807 -0.056513
#
#                                                topic12   topic13   topic14  \
# britney spears-plastic                        0.059598 -0.008154 -0.005247
# waits, tom-blue valentines                   -0.011899  0.043372 -0.011097
# elton john-i don't care                       0.084510 -0.014430 -0.128116
# beach boys-the little old lady from pasadena  0.047284  0.015405  0.024190
# waits, tom-she stole the blush               -0.044013  0.048858  0.004998
# aerosmith-love in an elevator                 0.007902  0.018312  0.020383
# aerosmith-deuces are wild                     0.032014  0.127859 -0.086870
# depeche mode-a pain that i'm used to         -0.046325  0.010678  0.108230
# eddie vedder-goodbye                         -0.037709  0.043814 -0.013997
# spice girls-love thing                       -0.076145  0.015504  0.048947
#
#                                                topic15
# britney spears-plastic                        0.080116
# waits, tom-blue valentines                   -0.012831
# elton john-i don't care                       0.151656
# beach boys-the little old lady from pasadena -0.045970
# waits, tom-she stole the blush               -0.029453
# aerosmith-love in an elevator                -0.009398
# aerosmith-deuces are wild                     0.022457
# depeche mode-a pain that i'm used to         -0.004679
# eddie vedder-goodbye                         -0.011322
# spice girls-love thing                        0.008072

# %%
#Most relevant words for each topic
num_terms = 20
for i in range(num_topics):
    print("___topic " + str(i) + "___")
    topicName = "topic" + str(i)
    weightedlist = topic_weights.get(topicName).sort_values()[-num_terms:]
    print(weightedlist.index.values)
# Out:
# ___topic 0___
# ["can't" "i'll" 'feel' 'make' "it's" 'wanna' 'say' 'need' 'tell' 'let'
#  'just' "you're" 'want' 'yeah' "i'm" 'oh' 'know' "don't" 'baby' 'love']
# ___topic 1___
# ['moon' 'hope' 'away' 'say' 'star' 'summer' 'real' 'tell' 'true' 'life'
#  'gone' 'world' "i've" 'eye' 'time' 'heart' 'fall' 'day' "it's" 'love']
# ___topic 2___
# ['mm' 'thank' 'bye' 'mmm' "darlin'" 'ooo' 'ho' 'ha' 'ah' 'sweet' 'la'
#  'ooh' 'whoa' 'oo' 'girl' 'hey' 'baby' 'yeah' 'love' 'oh']
# ___topic 3___
# ['tell' 'long' 'hard' 'like' 'home' 'standing' 'good' 'heart' 'think'
#  'alright' 'gone' "i've" "she's" 'time' 'gonna' "it's" 'yeah' 'know' "i'm"
#  'oh']
# ___topic 4___
# ['old' 'ready' 'pretty' 'honey' "that's" "you're" 'bad' 'blue' 'little'
#  'hey' "she's" "ain't" 'love' 'good' 'yeah' 'got' 'gonna' 'girl' 'baby'
#  "i'm"]
# ___topic 5___
# ['woman' 'round' 'really' 'talk' 'know' "ain't" 'dance' 'gotta' 'gonna'
#  'love' "she's" 'ah' 'boy' 'girl' 'got' 'la' 'wanna' 'yeah' 'hey' "don't"]
# ___topic 6___
# ["we're" 'world' 'win' 'home' 'come' 'feel' 'life' 'dream' 'wanna' 'music'
#  'hold' 'standing' "can't" "c'mon" "you're" 'gotta' "it's" 'hey' 'yeah'
#  'let']
# ___topic 7___
# ["'cause" 'fly' 'hold' 'hey' 'day' 'standing' "that's" 'tonight' 'kiss'
#  'let' 'try' 'really' 'dance' 'la' 'wanna' 'yeah' 'tell' "i'll" "i'm"
#  'want']
# ___topic 8___
# ["goin'" 'crazy' 'da' 'ba' 'na' 'ooh' 'trying' 'curious' 'ah' 'got'
#  'gonna' "c'mon" 'round' 'tell' 'honey' "don't" 'baby' 'love' 'let' "i'm"]
# ___topic 9___
# ['young' 'ooh' 'say' 'long' 'breathe' 'stop' 'feel' 'just' "i'm" 'da'
#  'like' 'oh' "can't" "don't" 'need' 'baby' 'hey' "it's" "you're" 'la']
# ___topic 10___
# ['round' 'say' "you'll" 'talk' "c'mon" 'world' 'la' 'long' 'gone' "i'm"
#  'little' 'tell' 'know' 'good' "she's" "you're" 'boy' 'hey' 'girl' 'let']
# ___topic 11___
# ['ba' "you'll" 'ooh' 'tomorrow' "'cause" "didn't" 'ah' 'gone' 'say' 'away'
#  'come' 'good' 'standing' "she's" 'day' 'life' 'tell' 'know' 'la' 'yeah']
# ___topic 12___
# ["c'mon" 'music' 'good' "i've" 'way' 'feel' 'hard' 'love' 'like' "ain't"
#  'time' 'want' 'just' "can't" 'dance' "she's" 'got' "it's" 'let' 'la']
# ___topic 13___
# ["we'll" 'away' 'tonight' 'summer' 'christmas' 'just' 'good' 'day'
#  'little' "i'll" 'night' 'home' 'like' "i'm" "don't" 'come' 'dream'
#  'wanna' 'girl' 'la']
# ___topic 14___
# ['yeah' 'round' 'true' 'stop' "i'll" 'love' 'christmas' "i'm" 'bad' 'na'
#  'know' "we're" "you're" 'day' "she's" 'dance' 'want' 'need' "it's" 'good']
# ___topic 15___
# ['need' 'fly' 'good' 'world' 'girl' "you'll" 'run' "i've" "you've" 'woman'
#  'gonna' 'day' "ain't" 'want' 'oh' 'come' 'let' 'la' 'got' "you're"]

# %% [markdown]
# Makes me think that "yeah" should be a stop word for song lyrics?

# %%
#Query some strings and see how they relate to topics
df = topic_weights.T["ooh whoa christmas".split()]
df.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_1e1ff_row0_col0, #T_1e1ff_row2_col1, #T_1e1ff_row13_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_1e1ff_row0_col1 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_1e1ff_row0_col2 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_1e1ff_row1_col0, #T_1e1ff_row4_col1, #T_1e1ff_row12_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_1e1ff_row1_col1, #T_1e1ff_row4_col0, #T_1e1ff_row5_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_1e1ff_row1_col2 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_1e1ff_row2_col0 {
#   background-color: #005e26;
#   color: #f1f1f1;
# }
# #T_1e1ff_row2_col2, #T_1e1ff_row3_col1 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_1e1ff_row3_col0 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_1e1ff_row3_col2 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_1e1ff_row4_col2 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_1e1ff_row5_col0 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_1e1ff_row5_col2 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_1e1ff_row6_col0 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_1e1ff_row6_col1 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_1e1ff_row6_col2 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_1e1ff_row7_col0 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_1e1ff_row7_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_1e1ff_row7_col2 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_1e1ff_row8_col0 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_1e1ff_row8_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_1e1ff_row8_col2 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_1e1ff_row9_col0 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_1e1ff_row9_col1 {
#   background-color: #97d492;
#   color: #000000;
# }
# #T_1e1ff_row9_col2 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_1e1ff_row10_col0 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_1e1ff_row10_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_1e1ff_row10_col2 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_1e1ff_row11_col0 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_1e1ff_row11_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_1e1ff_row11_col2 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_1e1ff_row12_col0 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_1e1ff_row12_col1 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_1e1ff_row13_col0 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_1e1ff_row13_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_1e1ff_row14_col0, #T_1e1ff_row15_col0 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_1e1ff_row14_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_1e1ff_row14_col2 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_1e1ff_row15_col1 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_1e1ff_row15_col2 {
#   background-color: #6abf71;
#   color: #000000;
# }
# </style>
# <table id="T_1e1ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e1ff_level0_col0" class="col_heading level0 col0" >ooh</th>
#       <th id="T_1e1ff_level0_col1" class="col_heading level0 col1" >whoa</th>
#       <th id="T_1e1ff_level0_col2" class="col_heading level0 col2" >christmas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e1ff_level0_row0" class="row_heading level0 row0" >topic0</th>
#       <td id="T_1e1ff_row0_col0" class="data row0 col0" >0.062398</td>
#       <td id="T_1e1ff_row0_col1" class="data row0 col1" >0.016103</td>
#       <td id="T_1e1ff_row0_col2" class="data row0 col2" >-0.028641</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row1" class="row_heading level0 row1" >topic1</th>
#       <td id="T_1e1ff_row1_col0" class="data row1 col0" >-0.081349</td>
#       <td id="T_1e1ff_row1_col1" class="data row1 col1" >0.012960</td>
#       <td id="T_1e1ff_row1_col2" class="data row1 col2" >0.021802</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row2" class="row_heading level0 row2" >topic2</th>
#       <td id="T_1e1ff_row2_col0" class="data row2 col0" >0.051036</td>
#       <td id="T_1e1ff_row2_col1" class="data row2 col1" >0.052496</td>
#       <td id="T_1e1ff_row2_col2" class="data row2 col2" >0.011664</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row3" class="row_heading level0 row3" >topic3</th>
#       <td id="T_1e1ff_row3_col0" class="data row3 col0" >-0.014966</td>
#       <td id="T_1e1ff_row3_col1" class="data row3 col1" >0.023576</td>
#       <td id="T_1e1ff_row3_col2" class="data row3 col2" >-0.005431</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row4" class="row_heading level0 row4" >topic4</th>
#       <td id="T_1e1ff_row4_col0" class="data row4 col0" >-0.013499</td>
#       <td id="T_1e1ff_row4_col1" class="data row4 col1" >-0.021980</td>
#       <td id="T_1e1ff_row4_col2" class="data row4 col2" >-0.009351</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row5" class="row_heading level0 row5" >topic5</th>
#       <td id="T_1e1ff_row5_col0" class="data row5 col0" >-0.017662</td>
#       <td id="T_1e1ff_row5_col1" class="data row5 col1" >0.013119</td>
#       <td id="T_1e1ff_row5_col2" class="data row5 col2" >-0.047153</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row6" class="row_heading level0 row6" >topic6</th>
#       <td id="T_1e1ff_row6_col0" class="data row6 col0" >0.009704</td>
#       <td id="T_1e1ff_row6_col1" class="data row6 col1" >0.004545</td>
#       <td id="T_1e1ff_row6_col2" class="data row6 col2" >-0.010108</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row7" class="row_heading level0 row7" >topic7</th>
#       <td id="T_1e1ff_row7_col0" class="data row7 col0" >-0.031302</td>
#       <td id="T_1e1ff_row7_col1" class="data row7 col1" >0.015441</td>
#       <td id="T_1e1ff_row7_col2" class="data row7 col2" >0.041362</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row8" class="row_heading level0 row8" >topic8</th>
#       <td id="T_1e1ff_row8_col0" class="data row8 col0" >0.036416</td>
#       <td id="T_1e1ff_row8_col1" class="data row8 col1" >0.008310</td>
#       <td id="T_1e1ff_row8_col2" class="data row8 col2" >-0.008629</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row9" class="row_heading level0 row9" >topic9</th>
#       <td id="T_1e1ff_row9_col0" class="data row9 col0" >0.039404</td>
#       <td id="T_1e1ff_row9_col1" class="data row9 col1" >0.008226</td>
#       <td id="T_1e1ff_row9_col2" class="data row9 col2" >-0.023128</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row10" class="row_heading level0 row10" >topic10</th>
#       <td id="T_1e1ff_row10_col0" class="data row10 col0" >-0.008395</td>
#       <td id="T_1e1ff_row10_col1" class="data row10 col1" >-0.012217</td>
#       <td id="T_1e1ff_row10_col2" class="data row10 col2" >-0.031772</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row11" class="row_heading level0 row11" >topic11</th>
#       <td id="T_1e1ff_row11_col0" class="data row11 col0" >0.040206</td>
#       <td id="T_1e1ff_row11_col1" class="data row11 col1" >-0.011939</td>
#       <td id="T_1e1ff_row11_col2" class="data row11 col2" >0.002424</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row12" class="row_heading level0 row12" >topic12</th>
#       <td id="T_1e1ff_row12_col0" class="data row12 col0" >-0.037044</td>
#       <td id="T_1e1ff_row12_col1" class="data row12 col1" >0.010338</td>
#       <td id="T_1e1ff_row12_col2" class="data row12 col2" >-0.100727</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row13" class="row_heading level0 row13" >topic13</th>
#       <td id="T_1e1ff_row13_col0" class="data row13 col0" >0.016698</td>
#       <td id="T_1e1ff_row13_col1" class="data row13 col1" >-0.017169</td>
#       <td id="T_1e1ff_row13_col2" class="data row13 col2" >0.083687</td>
#     </tr>
#     <tr>
#       <th id="T_1e1ff_level0_row14" class="row_heading level0 row14" >topic14</th>
#       <td id="T_1e1ff_row14_col0" class="data row14 col0" >0.011823</td>
#       <td id="T_1e1ff_row14_col1" class="data r

# %% [markdown]
# ## LDiA

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
#We calculate LDA on the Bag Of Words, NOT TFIDF
count_vectoriser = CountVectorizer(tokenizer=my_tokeniser)
bag_of_words = count_vectoriser.fit_transform(songs["Lyric"])
vocab = count_vectoriser.get_feature_names_out()

print(bag_of_words.todense().shape)
# Out:
# (1636, 12319)

# %%
lda = LatentDirichletAllocation(n_components=num_topics,
                                random_state=123,
                                learning_method='batch')

# %%
#May take some time depending on size of dataset!
lda_topics = lda.fit_transform(bag_of_words)

# %%
#How much does each topic apply to each song?
lda_topic_vectors_df = pd.DataFrame(lda_topics, index=songs["Title"].values, columns=labels)
lda_topic_vectors_df.sample(10)
# Out:
#                                                       topic0    topic1  \
# cohen, leonard-teachers                             0.000492  0.000492
# mitchell, joni-woodstock                            0.000702  0.000702
# elton john-dirty little girl                        0.000772  0.000772
# aerosmith-no more no more                           0.000619  0.000619
# beach boys-no-go showboat                           0.000687  0.000687
# kaiser chiefs-misery company                        0.000326  0.000326
# beatles, the-medley: kansas city / hey, hey, he...  0.367886  0.036960
# bob dylan-do right to me baby (do unto others)      0.000391  0.000391
# dusty springfield-here she comes                    0.125170  0.000772
# elton john-hey armadillo                            0.000613  0.000613
#
#                                                       topic2    topic3  \
# cohen, leonard-teachers                             0.000492  0.000492
# mitchell, joni-woodstock                            0.000702  0.000702
# elton john-dirty little girl                        0.000772  0.204296
# aerosmith-no more no more                           0.000619  0.000619
# beach boys-no-go showboat                           0.000687  0.000687
# kaiser chiefs-misery company                        0.000326  0.000326
# beatles, the-medley: kansas city / hey, hey, he...  0.000573  0.453877
# bob dylan-do right to me baby (do unto others)      0.000391  0.356762
# dusty springfield-here she comes                    0.000772  0.000772
# elton john-hey armadillo                            0.000613  0.000613
#
#                                                       topic4    topic5  \
# cohen, leonard-teachers                             0.000492  0.000492
# mitchell, joni-woodstock                            0.000702  0.000702
# elton john-dirty little girl                        0.051012  0.000772
# aerosmith-no more no more                           0.000619  0.199438
# beach boys-no-go showboat                           0.000687  0.000687
# kaiser chiefs-misery company                        0.000326  0.000326
# beatles, the-medley: kansas city / hey, hey, he...  0.134396  0.000573
# bob dylan-do right to me baby (do unto others)      0.000391  0.000391
# dusty springfield-here she comes                    0.000772  0.000772
# elton john-hey armadillo                            0.110814  0.000613
#
#                                                       topic6    topic7  \
# cohen, leonard-teachers                             0.000492  0.623860
# mitchell, joni-woodstock                            0.000702  0.924087
# elton john-dirty little girl                        0.503489  0.000772
# aerosmith-no more no more                           0.262609  0.000619
# beach boys-no-go showboat                           0.000687  0.000687
# kaiser chiefs-misery company                        0.000326  0.000326
# beatles, the-medley: kansas city / hey, hey, he...  0.000573  0.000573
# bob dylan-do right to me baby (do unto others)      0.035222  0.000391
# dusty springfield-here she comes                    0.000772  0.000772
# elton john-hey armadillo                            0.000613  0.000613
#
#                                                       topic8    topic9  \
# cohen, leonard-teachers                             0.000492  0.369250
# mitchell, joni-woodstock                            0.000702  0.000702
# elton john-dirty little girl                        0.000772  0.000772
# aerosmith-no more no more                           0.100388  0.000619
# beach boys-no-go showboat                           0.818213  0.000687
# kaiser chiefs-misery company                        0.000326  0.000326
# beatles, the-medley: kansas city / hey, hey, he...  0.000573  0.000573
# bob dylan-do right to me baby (do unto others)      0.000391  0.000391
# dusty springfield-here she comes                    0.083730  0.000772
# elton john-hey armadillo                            0.680158  0.000613
#
#                                                      topic10   topic11  \
# cohen, leonard-teachers                             0.000492  0.000492
# mitchell, joni-woodstock                            0.000702  0.000702
# elton john-dirty little girl                        0.000772  0.000772
# aerosmith-no more no more                           0.045572  0.000619
# beach boys-no-go showboat                           0.000687  0.172171
# kaiser chiefs-misery company                        0.000326  0.000326
# beatles, the-medley: kansas city / hey, hey, he...  0.000573  0.000573
# bob dylan-do right to me baby (do unto others)      0.000391  0.000391
# dusty springfield-here she comes                    0.000772  0.000772
# elton john-hey armadillo                            0.000613  0.000613
#
#                                                      topic12   topic13  \
# cohen, leonard-teachers                             0.000492  0.000492
# mitchell, joni-woodstock                            0.066081  0.000702
# elton john-dirty little girl                        0.000772  0.000772
# aerosmith-no more no more                           0.337433  0.000619
# beach boys-no-go showboat                           0.000687  0.000687
# kaiser chiefs-misery company                        0.995117  0.000326
# beatles, the-medley: kansas city / hey, hey, he...  0.000573  0.000573
# bob dylan-do right to me baby (do unto others)      0.000391  0.000391
# dusty springfield-here she comes                    0.000772  0.000772
# elton john-hey armadillo                            0.000613  0.000613
#
#                                                      topic14   topic15
# cohen, leonard-teachers                             0.000492  0.000492
# mitchell, joni-woodstock                            0.000702  0.000702
# elton john-dirty little girl                        0.000772  0.231944
# aerosmith-no more no more                           0.000619  0.048372
# beach boys-no-go showboat                           0.000687  0.000687
# kaiser chiefs-misery company                        0.000326  0.000326
# beatles, the-medley: kansas city / hey, hey, he...  0.000573  0.000573
# bob dylan-do right to me baby (do unto others)      0.000391  0.602938
# dusty springfield-here she comes                    0.030139  0.751701
# elton john-hey armadillo                            0.000613  0.201063

# %% [markdown]
# ### Comparing distributions of SVD and LDA
#
# How are the distributions of topic scores different for SVD and LSA? Compare the results for the same song

# %%
song_name = 'portishead-mysterons'

# %%
svd_topic_vectors_df.loc[song_name]
# Out:
# topic0    -0.033149
# topic1    -0.086843
# topic2    -0.019210
# topic3    -0.144541
# topic4    -0.010099
# topic5     0.040664
# topic6    -0.185396
# topic7     0.258922
# topic8    -0.105410
# topic9    -0.066661
# topic10   -0.092530
# topic11    0.001251
# topic12    0.058855
# topic13   -0.166626
# topic14    0.093101
# topic15   -0.017662
# Name: portishead-mysterons, dtype: float64

# %%
lda_topic_vectors_df.loc[song_name]
# Out:
# topic0     0.001389
# topic1     0.001389
# topic2     0.001389
# topic3     0.001389
# topic4     0.001389
# topic5     0.001389
# topic6     0.001389
# topic7     0.001389
# topic8     0.001389
# topic9     0.001389
# topic10    0.001389
# topic11    0.001389
# topic12    0.001389
# topic13    0.001389
# topic14    0.001389
# topic15    0.979167
# Name: portishead-mysterons, dtype: float64

# %%
#Highest scoring songs for each topic
for topic in labels:
    print(topic)
    #Get last songs 10 in list (highest scoring for each topic)
    print(songs["Title"].values[lda_topic_vectors_df[topic].argsort().values[-10:]])
# Out:
# topic0
# ['elton john-queen of cities (el dorado ii)' 'britney spears-better'
#  'dusty springfield-mockingbird' 'beach boys-help me, rhonda'
#  'beatles, the-i am the walrus' 'waits, tom-diamonds on my windshield'
#  'waits, tom-murder in the red barn' 'britney spears-liar'
#  'waits, tom-hell broke luce'
#  'britney spears-till the world ends (alex suarez club remix)']
# topic1
# ['depeche mode-lilian' 'elton john-take me to the pilot'
#  'manic street preachers-dead martyrs'
#  'kaiser chiefs-dead or in serious trouble' 'bob dylan-paths of victory'
#  'aerosmith-cheese cake' 'beach boys-hushabye' "beatles, the-searchin'"
#  'aerosmith-lightning strikes' 'beach boys-pitter patter']
# topic2
# ['manic street preachers-tsunami'
#  'manic street preachers-another invented disease'
#  'elton john-my quicksand' 'waits, tom-in the colosseum'
#  'elton john-the new fever waltz' 'dusty springfield-heartbeat'
#  'bruce springsteen-breakaway' 'beach boys-palisades park'
#  'basement jaxx-get me off' 'de la soul-property of spitkicker.com']
# topic3
# ['elton john-2 fingers of whiskey' 'dusty springfield-live it up'
#  'manic street preachers-new art riot' 'cliff, jimmy-no woman no cry'
#  'manic street preachers-repeat (stars and stripes)'
#  "beach boys-shortenin' bread" "basement jaxx-right here's the spot"
#  'elton john-bennie and the jets (2018 version)'
#  "beach boys-still cruisin'" 'aerosmith-f.i.n.e.']
# topic4
# ["bruce springsteen-santa claus is comin' to town" 'beach boys-in my car'
#  'aerosmith-chip away the stone' 'cliff, jimmy-hello sunshine'
#  'britney spears-3' 'beatles, the-hello, goodbye'
#  'smokey robinson-gang bangin'
#  'britney spears-3 (manhattan clique club remix)'
#  'beach boys-student demonstration time' 'britney spears-soda pop']
# topic5
# ['beach boys-sail on sailor' 'bob dylan-shenandoah'
#  'bob dylan-death is not the end' 'bob dylan-political world'
#  'waits, tom-singapore' 'beach boys-cabinessence' 'editors-black gold'
#  'les miserables cast-one day more!' 'sigur ros-illgresi'
#  'editors-barricades']
# topic6
# ['beach boys-pom pom play girl' 'bob dylan-dirge'
#  'waits, tom-big in japan' 'mitchell, joni-the circle game'
#  'editors-magazine' 'mitchell, joni-dog eat dog'
#  'waits, tom-bottom of the world' 'beach boys-little saint nick'
#  "britney spears-chillin' with you"
#  'de la soul-plug tunin\' (original 12 version)"']
# topic7
# ['elton john-candle in the wind' 'elton john-monkey suit'
#  'mitchell, joni-nathan la franeer' "waits, tom-what's he building?"
#  'beach boys-the private life of bill and sue' 'beach boys-chug-a-lug'
#  'basement jaxx-jus 1 kiss' 'waits, tom-satisfied'
#  'echo & the bunnymen-in my time' 'britney spears-me against the music']
# topic8
# ['kaiser chiefs-little shocks' 'elton john-eight hundred dollar shoes'
#  "basement jaxx-u can't stop me" 'beach boys-amusement parks u.s.a.'
#  'bruce springsteen-balboa park' 'beach boys-heads you win, tails i lose'
#  "britney spears-early mornin' (jason nevins remix)"
#  'les miserables cast-master of the house' 'britney spears-tik tik boom'
#  "de la soul-ego trippin' (part two)"]
# topic9
# ['cohen, leonard-the night of santiago' 'beach boys-strange things happen'
#  'sigur ros-gobbledigook'
#  'dan le sac vs scroobius pip-the beat that my heart skipped'
#  'bob dylan-when you gonna wake up ?' 'sigur ros-heima'
#  'britney spears-just luv me' 'bob dylan-the ballad of ira hayes'
#  "bob dylan-a hard rain's a-gonna fall"
#  "cliff, jimmy-a hard rain's a-gonna fall"]
# topic10
# ['aerosmith-bone to bone (coney island white fish boy)'
#  'sigur ros-heysatan' 'beach boys-spirit of america'
#  "manic street preachers-love's sweet exile" 'beach boys-do you remember'
#  'cliff, jimmy-johnny too bad' 'bruce springsteen-shackled and drawn'
#  'manic street preachers-miss europa disco dancer'
#  'beach boys-cool cool water' 'beach boys-alley oop']
# topic11
# ['beach boys-cherry, cherry coupe' 'beatles, the-yellow submarine'
#  'beach boys-feel flows' 'mitchell, joni-the jungle line'
#  'beatles, the-across the universe'
#  "manic street preachers-rock 'n' roll music" 'britney spears-body ache'
#  'britney spears-slumber party (bad royale remix)'
#  'britney spears-slumber party' 'britney spears-slumber party']
# topic12
# ['manic street preachers-dead passive' 'sigur ros-hoppipolla'
#  'aerosmith-jesus is on the main line' 'editors-when we were angels'
#  'waits, tom-heartattack and vine' 'editors-nothingness'
#  'bob dylan-trade winds' 'kaiser chiefs-misery company'
#  "waits, tom-whistlin' past the graveyard"
#  'sigur ros-inni mer syngur vitleysingur']
# topic13
# ['aerosmith-monkey on my back' "de la soul-long island wildin'"
#  "bob dylan-fixin' to die blues" "bob dylan-knockin' on heaven's door"
#  'sigur ros-fljotavik' 'manic street preachers-distractions'
#  'manic street preachers-caldey' "beach boys-surfin' usa"
#  'beatles, the-shout' "beach boys-surfin'"]
# topic14
# ['kaiser chiefs-sink that ship' 'aerosmith-my fist your face'
#  'bruce springsteen-the little things (my baby does)'
#  "beach boys-in the still of the night (i'll remember)"
#  'beach boys-the little old lady from pasadena'
#  'bob dylan-little drummer boy' 'bob dylan-million dollar bash'
#  'britney spears-mmm papi' 'britney spears-gimme more'
#  'britney spears-change your mind (no seas cortes)']
# topic15
# ['britney spears-perfume' 'britney spears-born to make you happy'
#  'elton john-step into christmas' 'britney spears-plastic'
#  'cliff, jimmy-blessed love' 'britney spears-my only wish this year'
#  'britney spears-brave new girl' 'bruce springsteen-point blank'
#  'spice girls-love thing' 'dan le sac vs scroobius pip-look for the woman']

# %%
#Most relevant tokens for each topic
for i, topic in enumerate(lda.components_):
    print("topic " + str(i) + ":")
    #Get last n tokens (highest values)
    print(vocab[topic.argsort()[-num_terms:]])
# Out:
# topic 0:
# ['just' 'said' "don't" 'wo' 'rhonda' "she's" 'way' 'dorado' 'el' "it's"
#  'come' 'gonna' 'let' 'bye' 'home' "i'm" 'like' 'help' 'know' 'oh']
# topic 1:
# ['fall' 'road' 'look' 'like' 'cuckoo' "i'm" 'gonna' 'dead' 'fun' 'just'
#  'pitter' "what's" 'got' 'star' 'patter' 'light' 'oh' 'yeah' 'ooo' 'ah']
# topic 2:
# ['waiting' 'come' "we've" 'night' 'cold' 'mind' "won't" 'got' 'yeah'
#  'like' 'went' "i'm" 'just' 'body' 'need' 'oh' 'baby' 'kiss' 'heart'
#  "it's"]
# topic 3:
# ['like' 'woman' 'little' 'shake' 'bad' 'street' "it's" 'blue' 'right'
#  'gonna' 'gotta' 'love' "you're" "ain't" 'come' 'good' "i'm" 'baby' 'got'
#  'yeah']
# topic 4:
# ['stop' 'bring' 'love' 'talk' 'better' 'day' 'know' "can't" 'boy' 'god'
#  'time' 'little' 'come' 'yeah' 'oh' 'say' "don't" 'let' "i'm" 'hey']
# topic 5:
# ['like' "it's" 'wind' 'tell' 'eye' 'look' 'lonely' "you'll" 'come' 'live'
#  'time' 'day' 'run' 'world' 'life' 'just' "you're" 'away' 'know' "don't"]
# topic 6:
# ["we're" 'thing' 'love' 'lost' 'number' 'just' 'play' 'time' "there's"
#  'little' 'know' 'man' "she's" "you're" "don't" "it's" 'like' 'round'
#  'got' "i'm"]
# topic 7:
# ['people' 'got' "there's" 'make' 'night' 'eye' 'gone' 'long' 'mother'
#  'world' "i'll" 'life' 'know' "it's" 'let' 'day' 'just' 'like' "i'm" 'la']
# topic 8:
# ['xo' 'lady' 'head' 'lot' 'look' 'oh' 'little' 'ay' "can't" "it's" 'money'
#  'just' 'make' 'tick' "i'm" 'like' 'da' "don't" 'know' 'got']
# topic 9:
# ['tell' 'think' 'night' "i've" 'thing' 'got' 'did' 'hard' 'strange' "i'll"
#  'like' 'man' 'na' 'gonna' "it's" 'oh' "don't" 'just' "i'm" 'need']
# topic 10:
# ['big' 'blowing' 'hope' 'hello' 'say' 'got' 'like' "she's" 'night' 'whoa'
#  'real' "it's" 'j' 'ho' 'morning' 'water' "you're" 'cool' 'oop' 'good']
# topic 11:
# ["it's" 'dumb' 'yellow' 'crazy' 'dance' 'old' 'cherry' 'hanging' 'body'
#  'slumber' 'gonna' 'party' 'use' 'got' 'rock' 'make' 'music' 'young'
#  'roll' 'like']
# topic 12:
# ['angel' 'just' "ain't" 'make' "goin'" 'know' 'wind' 'song' 'trade' "it's"
#  'tell' 'come' 'oh' "i'm" "we're" 'dance' 'time' 'baby' 'want' 'ha']
# topic 13:
# ["won't" 'yeah' 'said' 'day' 'mama' 'gonna' 'burning' 'somebody' 'knock'
#  'ba' 'tell' 'think' 'dip' 'dit' 'hey' "i'm" "surfin'" 'shout' 'di' 'bom']
# topic 14:
# ['say' 'night' 'oh' 'sweet' 'mmm' "i'll" 'day' 'pum' 'make' 'good' "don't"
#  'right' 'honey' 'thing' "it's" 'love' 'gimme' "i'm" 'ooh' 'baby']
# topic 15:
# ['girl' 'make' 'feel' "i'll" 'tell' "can't" 'way' 'time' 'oh' "you're"
#  'come' 'like' 'want' 'baby' "it's" 'just' 'know' "i'm" "don't" 'love']
